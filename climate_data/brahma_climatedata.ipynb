# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Contents of Notebook
#
# **Part 1: Imports climate data, concatenate all records, and plot data for visualization (reference, rcp4.5 and rcp8.5 scenarios)**
#
# **Part 2: Calculates mean annual and mean daily precipitation and temperature for the rcp8.5 scenario, then plots results**

# %% [markdown]
# ## Part 1: Import climate data and concatenate all records (reference, rcp4.5 and rcp8.5 scenarios)
#
# ### 1.1. RCP4P5
#
# #### 1.1a) Load Climate Data

# %%
gfdl_2000_4p5_csv = pd.read_csv('Brahmaputra/reference/GFDL-ESM2M/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2020_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/GFDL-ESM2M/2020/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2040_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/GFDL-ESM2M/2040/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2060_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/GFDL-ESM2M/2060/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2080_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/GFDL-ESM2M/2080/HYDRO.CLIMATE', delimiter = "\t")

hadgem_2000_4p5_csv = pd.read_csv('Brahmaputra/reference/HadGEM2/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2020_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/HadGEM2/2020/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2040_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/HadGEM2/2040/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2060_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/HadGEM2/2060/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2080_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/HadGEM2/2080/HYDRO.CLIMATE', delimiter = "\t")

ipsl_2000_4p5_csv = pd.read_csv('Brahmaputra/reference/IPSL_CM5A/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2020_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/IPSL_CM5A/2020/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2040_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/IPSL_CM5A/2040/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2060_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/IPSL_CM5A/2060/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2080_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/IPSL_CM5A/2080/HYDRO.CLIMATE', delimiter = "\t")

miroc_2000_4p5_csv = pd.read_csv('Brahmaputra/reference/MIROC-ESM-CHEM/HYDRO.CLIMATE', delimiter = "\t")
miroc_2020_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/MIROC-ESM-CHEM/2020/HYDRO.CLIMATE', delimiter = "\t")
miroc_2040_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/MIROC-ESM-CHEM/2040/HYDRO.CLIMATE', delimiter = "\t")
miroc_2060_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/MIROC-ESM-CHEM/2060/HYDRO.CLIMATE', delimiter = "\t")
miroc_2080_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/MIROC-ESM-CHEM/2080/HYDRO.CLIMATE', delimiter = "\t")

noresm_2000_4p5_csv = pd.read_csv('Brahmaputra/reference/NORESM-M/HYDRO.CLIMATE', delimiter = "\t")
noresm_2020_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/NORESM-M/2020/HYDRO.CLIMATE', delimiter = "\t")
noresm_2040_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/NORESM-M/2040/HYDRO.CLIMATE', delimiter = "\t")
noresm_2060_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/NORESM-M/2060/HYDRO.CLIMATE', delimiter = "\t")
noresm_2080_4p5_csv = pd.read_csv('Brahmaputra/rcp4p5/NORESM-M/2080/HYDRO.CLIMATE', delimiter = "\t")

# %% [markdown]
# #### 1.1b) Clean up dataframes
# - Clip the headings from the data (first 6 lines)
# - Also clip the datasets in the middle of the time period, since the datasets overlap

# %%
gfdl_2000_4p5 = pd.DataFrame(gfdl_2000_4p5_csv[6:])
gfdl_2020_4p5 = pd.DataFrame(gfdl_2020_4p5_csv[6:7301])
gfdl_2040_4p5 = pd.DataFrame(gfdl_2040_4p5_csv[6:7301])
gfdl_2060_4p5 = pd.DataFrame(gfdl_2060_4p5_csv[6:7301])
gfdl_2080_4p5 = pd.DataFrame(gfdl_2080_4p5_csv[6:])

hadgem_2000_4p5 = pd.DataFrame(hadgem_2000_4p5_csv[6:])
hadgem_2020_4p5 = pd.DataFrame(hadgem_2020_4p5_csv[6:7301])
hadgem_2040_4p5 = pd.DataFrame(hadgem_2040_4p5_csv[6:7301])
hadgem_2060_4p5 = pd.DataFrame(hadgem_2060_4p5_csv[6:7301])
hadgem_2080_4p5 = pd.DataFrame(hadgem_2080_4p5_csv[6:])

ipsl_2000_4p5 = pd.DataFrame(ipsl_2000_4p5_csv[6:])
ipsl_2020_4p5 = pd.DataFrame(ipsl_2020_4p5_csv[6:7301])
ipsl_2040_4p5 = pd.DataFrame(ipsl_2040_4p5_csv[6:7301])
ipsl_2060_4p5 = pd.DataFrame(ipsl_2060_4p5_csv[6:7301])
ipsl_2080_4p5 = pd.DataFrame(ipsl_2080_4p5_csv[6:])

miroc_2000_4p5 = pd.DataFrame(miroc_2000_4p5_csv[6:])
miroc_2020_4p5 = pd.DataFrame(miroc_2020_4p5_csv[6:7301])
miroc_2040_4p5 = pd.DataFrame(miroc_2040_4p5_csv[6:7301])
miroc_2060_4p5 = pd.DataFrame(miroc_2060_4p5_csv[6:7301])
miroc_2080_4p5 = pd.DataFrame(miroc_2080_4p5_csv[6:])

noresm_2000_4p5 = pd.DataFrame(noresm_2000_4p5_csv[6:])
noresm_2020_4p5 = pd.DataFrame(noresm_2020_4p5_csv[6:7301])
noresm_2040_4p5 = pd.DataFrame(noresm_2040_4p5_csv[6:7301])
noresm_2060_4p5 = pd.DataFrame(noresm_2060_4p5_csv[6:7301])
noresm_2080_4p5 = pd.DataFrame(noresm_2080_4p5_csv[6:])

# %% [markdown]
# #### 1.1c) Assign column names for dataframes

# %%
gfdl_2020_4p5.reset_index(level=0, inplace=True)
gfdl_2020_4p5.columns = ['Precip', 'Temp']
gfdl_2040_4p5.reset_index(level=0, inplace=True)
gfdl_2040_4p5.columns = ['Precip', 'Temp']
gfdl_2060_4p5.reset_index(level=0, inplace=True)
gfdl_2060_4p5.columns = ['Precip', 'Temp']
gfdl_2080_4p5.reset_index(level=0, inplace=True)
gfdl_2080_4p5.columns = ['Precip', 'Temp']

hadgem_2000_4p5.reset_index(level=0, inplace=True)
hadgem_2000_4p5.columns = ['Precip', 'Temp']
hadgem_2020_4p5.reset_index(level=0, inplace=True)
hadgem_2020_4p5.columns = ['Precip', 'Temp']
hadgem_2040_4p5.reset_index(level=0, inplace=True)
hadgem_2040_4p5.columns = ['Precip', 'Temp']
hadgem_2060_4p5.reset_index(level=0, inplace=True)
hadgem_2060_4p5.columns = ['Precip', 'Temp']
hadgem_2080_4p5.reset_index(level=0, inplace=True)
hadgem_2080_4p5.columns = ['Precip', 'Temp']

ipsl_2000_4p5.reset_index(level=0, inplace=True)
ipsl_2000_4p5.columns = ['Precip', 'Temp']
ipsl_2020_4p5.reset_index(level=0, inplace=True)
ipsl_2020_4p5.columns = ['Precip', 'Temp']
ipsl_2040_4p5.reset_index(level=0, inplace=True)
ipsl_2040_4p5.columns = ['Precip', 'Temp']
ipsl_2060_4p5.reset_index(level=0, inplace=True)
ipsl_2060_4p5.columns = ['Precip', 'Temp']
ipsl_2080_4p5.reset_index(level=0, inplace=True)
ipsl_2080_4p5.columns = ['Precip', 'Temp']

miroc_2000_4p5.reset_index(level=0, inplace=True)
miroc_2000_4p5.columns = ['Precip', 'Temp']
miroc_2020_4p5.reset_index(level=0, inplace=True)
miroc_2020_4p5.columns = ['Precip', 'Temp']
miroc_2040_4p5.reset_index(level=0, inplace=True)
miroc_2040_4p5.columns = ['Precip', 'Temp']
miroc_2060_4p5.reset_index(level=0, inplace=True)
miroc_2060_4p5.columns = ['Precip', 'Temp']
miroc_2080_4p5.reset_index(level=0, inplace=True)
miroc_2080_4p5.columns = ['Precip', 'Temp']

noresm_2000_4p5.reset_index(level=0, inplace=True)
noresm_2000_4p5.columns = ['Precip', 'Temp']
noresm_2020_4p5.reset_index(level=0, inplace=True)
noresm_2020_4p5.columns = ['Precip', 'Temp']
noresm_2040_4p5.reset_index(level=0, inplace=True)
noresm_2040_4p5.columns = ['Precip', 'Temp']
noresm_2060_4p5.reset_index(level=0, inplace=True)
noresm_2060_4p5.columns = ['Precip', 'Temp']
noresm_2080_4p5.reset_index(level=0, inplace=True)
noresm_2080_4p5.columns = ['Precip', 'Temp']

# %% [markdown]
# #### 1.1d) Concatenate dataframes to obtain one record with all climate data for each model

# %%
gfdl_4p5 = pd.concat([gfdl_2000_4p5, gfdl_2020_4p5, gfdl_2040_4p5, gfdl_2060_4p5, gfdl_2080_4p5], axis = 0).astype(float)
hadgem_4p5 = pd.concat([hadgem_2000_4p5, hadgem_2020_4p5, hadgem_2040_4p5, hadgem_2060_4p5, hadgem_2080_4p5], axis = 0).astype(float)
ipsl_4p5 = pd.concat([ipsl_2000_4p5, ipsl_2020_4p5, ipsl_2040_4p5, ipsl_2060_4p5, ipsl_2080_4p5], axis = 0).astype(float)
miroc_4p5 = pd.concat([miroc_2000_4p5, miroc_2020_4p5, miroc_2040_4p5, miroc_2060_4p5, miroc_2080_4p5], axis = 0).astype(float)
noresm_4p5 = pd.concat([noresm_2000_4p5, noresm_2020_4p5, noresm_2040_4p5, noresm_2060_4p5, noresm_2080_4p5], axis = 0).astype(float)

# %% [markdown]
# #### 1.1e) Reshape arrays to get mean annual temperature

# %%
gfdl_temp_4p5 = np.array(gfdl_4p5['Temp'], dtype = float)
gfdl_temp_reshape_4p5 = gfdl_temp_4p5.reshape(120,365)
gfdl_temp_rows_4p5 = np.mean(gfdl_temp_reshape_4p5, axis = 1)

hadgem_temp_4p5 = np.array(hadgem_4p5['Temp'], dtype = float)
hadgem_temp_reshape_4p5 = hadgem_temp_4p5.reshape(120,365)
hadgem_temp_rows_4p5 = np.mean(hadgem_temp_reshape_4p5, axis = 1)

ipsl_temp_4p5 = np.array(ipsl_4p5['Temp'], dtype = float)
ipsl_temp_reshape_4p5 = ipsl_temp_4p5.reshape(120,365)
ipsl_temp_rows_4p5 = np.mean(ipsl_temp_reshape_4p5, axis = 1)

miroc_temp_4p5 = np.array(miroc_4p5['Temp'], dtype = float)
miroc_temp_reshape_4p5 = miroc_temp_4p5.reshape(120,365)
miroc_temp_rows_4p5 = np.mean(miroc_temp_reshape_4p5, axis = 1)

noresm_temp_4p5 = np.array(noresm_4p5['Temp'], dtype = float)
noresm_temp_reshape_4p5 = noresm_temp_4p5.reshape(120,365)
noresm_temp_rows_4p5 = np.mean(noresm_temp_reshape_4p5, axis = 1)

# %% [markdown]
# #### 1.1f) Reshape arrays to get mean annual precipitation

# %%
gfdl_prec_4p5 = np.array(gfdl_4p5['Precip'], dtype = float)
gfdl_prec_reshape_4p5 = gfdl_prec_4p5.reshape(120,365)
gfdl_prec_rows_4p5 = np.mean(gfdl_prec_reshape_4p5, axis = 1)

hadgem_prec_4p5 = np.array(hadgem_4p5['Precip'], dtype = float)
hadgem_prec_reshape_4p5 = hadgem_prec_4p5.reshape(120,365)
hadgem_prec_rows_4p5 = np.mean(hadgem_prec_reshape_4p5, axis = 1)

ipsl_prec_4p5 = np.array(ipsl_4p5['Precip'], dtype = float)
ipsl_prec_reshape_4p5 = ipsl_prec_4p5.reshape(120,365)
ipsl_prec_rows_4p5 = np.mean(ipsl_prec_reshape_4p5, axis = 1)

miroc_prec_4p5 = np.array(miroc_4p5['Precip'], dtype = float)
miroc_prec_reshape_4p5 = miroc_prec_4p5.reshape(120,365)
miroc_prec_rows_4p5 = np.mean(miroc_prec_reshape_4p5, axis = 1)

noresm_prec_4p5 = np.array(noresm_4p5['Precip'], dtype = float)
noresm_prec_reshape_4p5 = noresm_prec_4p5.reshape(120,365)
noresm_prec_rows_4p5 = np.mean(noresm_prec_reshape_4p5, axis = 1)

# %% [markdown]
# ### 1.2. RCP8P5
#
# #### 1.2a) Load Climate Data

# %%
gfdl_2000_8p5_csv = pd.read_csv('Brahmaputra/reference/GFDL-ESM2M/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2020_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/GFDL-ESM2M/2020/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2040_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/GFDL-ESM2M/2040/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2060_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/GFDL-ESM2M/2060/HYDRO.CLIMATE', delimiter = "\t")
gfdl_2080_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/GFDL-ESM2M/2080/HYDRO.CLIMATE', delimiter = "\t")

hadgem_2000_8p5_csv = pd.read_csv('Brahmaputra/reference/HadGEM2/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2020_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/HadGEM2/2020/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2040_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/HadGEM2/2040/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2060_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/HadGEM2/2060/HYDRO.CLIMATE', delimiter = "\t")
hadgem_2080_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/HadGEM2/2080/HYDRO.CLIMATE', delimiter = "\t")

ipsl_2000_8p5_csv = pd.read_csv('Brahmaputra/reference/IPSL_CM5A/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2020_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/IPSL_CM5A/2020/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2040_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/IPSL_CM5A/2040/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2060_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/IPSL_CM5A/2060/HYDRO.CLIMATE', delimiter = "\t")
ipsl_2080_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/IPSL_CM5A/2080/HYDRO.CLIMATE', delimiter = "\t")

miroc_2000_8p5_csv = pd.read_csv('Brahmaputra/reference/MIROC-ESM-CHEM/HYDRO.CLIMATE', delimiter = "\t")
miroc_2020_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/MIROC-ESM-CHEM/2020/HYDRO.CLIMATE', delimiter = "\t")
miroc_2040_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/MIROC-ESM-CHEM/2040/HYDRO.CLIMATE', delimiter = "\t")
miroc_2060_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/MIROC-ESM-CHEM/2060/HYDRO.CLIMATE', delimiter = "\t")
miroc_2080_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/MIROC-ESM-CHEM/2080/HYDRO.CLIMATE', delimiter = "\t")

noresm_2000_8p5_csv = pd.read_csv('Brahmaputra/reference/NORESM-M/HYDRO.CLIMATE', delimiter = "\t")
noresm_2020_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/NORESM-M/2020/HYDRO.CLIMATE', delimiter = "\t")
noresm_2040_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/NORESM-M/2040/HYDRO.CLIMATE', delimiter = "\t")
noresm_2060_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/NORESM-M/2060/HYDRO.CLIMATE', delimiter = "\t")
noresm_2080_8p5_csv = pd.read_csv('Brahmaputra/rcp8p5/NORESM-M/2080/HYDRO.CLIMATE', delimiter = "\t")

# %% [markdown]
# #### 1.2b) Clean up dataframes

# %%
gfdl_2000_8p5 = pd.DataFrame(gfdl_2000_8p5_csv[6:])
gfdl_2020_8p5 = pd.DataFrame(gfdl_2020_8p5_csv[6:7301])
gfdl_2040_8p5 = pd.DataFrame(gfdl_2040_8p5_csv[6:7301])
gfdl_2060_8p5 = pd.DataFrame(gfdl_2060_8p5_csv[6:7301])
gfdl_2080_8p5 = pd.DataFrame(gfdl_2080_8p5_csv[6:])

hadgem_2000_8p5 = pd.DataFrame(hadgem_2000_8p5_csv[6:])
hadgem_2020_8p5 = pd.DataFrame(hadgem_2020_8p5_csv[6:7301])
hadgem_2040_8p5 = pd.DataFrame(hadgem_2040_8p5_csv[6:7301])
hadgem_2060_8p5 = pd.DataFrame(hadgem_2060_8p5_csv[6:7301])
hadgem_2080_8p5 = pd.DataFrame(hadgem_2080_8p5_csv[6:])

ipsl_2000_8p5 = pd.DataFrame(ipsl_2000_8p5_csv[6:])
ipsl_2020_8p5 = pd.DataFrame(ipsl_2020_8p5_csv[6:7301])
ipsl_2040_8p5 = pd.DataFrame(ipsl_2040_8p5_csv[6:7301])
ipsl_2060_8p5 = pd.DataFrame(ipsl_2060_8p5_csv[6:7301])
ipsl_2080_8p5 = pd.DataFrame(ipsl_2080_8p5_csv[6:])

miroc_2000_8p5 = pd.DataFrame(miroc_2000_8p5_csv[6:])
miroc_2020_8p5 = pd.DataFrame(miroc_2020_8p5_csv[6:7301])
miroc_2040_8p5 = pd.DataFrame(miroc_2040_8p5_csv[6:7301])
miroc_2060_8p5 = pd.DataFrame(miroc_2060_8p5_csv[6:7301])
miroc_2080_8p5 = pd.DataFrame(miroc_2080_8p5_csv[6:])

noresm_2000_8p5 = pd.DataFrame(noresm_2000_8p5_csv[6:])
noresm_2020_8p5 = pd.DataFrame(noresm_2020_8p5_csv[6:7301])
noresm_2040_8p5 = pd.DataFrame(noresm_2040_8p5_csv[6:7301])
noresm_2060_8p5 = pd.DataFrame(noresm_2060_8p5_csv[6:7301])
noresm_2080_8p5 = pd.DataFrame(noresm_2080_8p5_csv[6:])

# %% [markdown]
# #### 1.2c) Assign column names for dataframes

# %%
gfdl_2000_8p5.reset_index(level=0, inplace=True)
gfdl_2000_8p5.columns = ['Precip', 'Temp']
gfdl_2020_8p5.reset_index(level=0, inplace=True)
gfdl_2020_8p5.columns = ['Precip', 'Temp']
gfdl_2040_8p5.reset_index(level=0, inplace=True)
gfdl_2040_8p5.columns = ['Precip', 'Temp']
gfdl_2060_8p5.reset_index(level=0, inplace=True)
gfdl_2060_8p5.columns = ['Precip', 'Temp']
gfdl_2080_8p5.reset_index(level=0, inplace=True)
gfdl_2080_8p5.columns = ['Precip', 'Temp']

hadgem_2000_8p5.reset_index(level=0, inplace=True)
hadgem_2000_8p5.columns = ['Precip', 'Temp']
hadgem_2020_8p5.reset_index(level=0, inplace=True)
hadgem_2020_8p5.columns = ['Precip', 'Temp']
hadgem_2040_8p5.reset_index(level=0, inplace=True)
hadgem_2040_8p5.columns = ['Precip', 'Temp']
hadgem_2060_8p5.reset_index(level=0, inplace=True)
hadgem_2060_8p5.columns = ['Precip', 'Temp']
hadgem_2080_8p5.reset_index(level=0, inplace=True)
hadgem_2080_8p5.columns = ['Precip', 'Temp']

ipsl_2000_8p5.reset_index(level=0, inplace=True)
ipsl_2000_8p5.columns = ['Precip', 'Temp']
ipsl_2020_8p5.reset_index(level=0, inplace=True)
ipsl_2020_8p5.columns = ['Precip', 'Temp']
ipsl_2040_8p5.reset_index(level=0, inplace=True)
ipsl_2040_8p5.columns = ['Precip', 'Temp']
ipsl_2060_8p5.reset_index(level=0, inplace=True)
ipsl_2060_8p5.columns = ['Precip', 'Temp']
ipsl_2080_8p5.reset_index(level=0, inplace=True)
ipsl_2080_8p5.columns = ['Precip', 'Temp']

miroc_2000_8p5.reset_index(level=0, inplace=True)
miroc_2000_8p5.columns = ['Precip', 'Temp']
miroc_2020_8p5.reset_index(level=0, inplace=True)
miroc_2020_8p5.columns = ['Precip', 'Temp']
miroc_2040_8p5.reset_index(level=0, inplace=True)
miroc_2040_8p5.columns = ['Precip', 'Temp']
miroc_2060_8p5.reset_index(level=0, inplace=True)
miroc_2060_8p5.columns = ['Precip', 'Temp']
miroc_2080_8p5.reset_index(level=0, inplace=True)
miroc_2080_8p5.columns = ['Precip', 'Temp']

noresm_2000_8p5.reset_index(level=0, inplace=True)
noresm_2000_8p5.columns = ['Precip', 'Temp']
noresm_2020_8p5.reset_index(level=0, inplace=True)
noresm_2020_8p5.columns = ['Precip', 'Temp']
noresm_2040_8p5.reset_index(level=0, inplace=True)
noresm_2040_8p5.columns = ['Precip', 'Temp']
noresm_2060_8p5.reset_index(level=0, inplace=True)
noresm_2060_8p5.columns = ['Precip', 'Temp']
noresm_2080_8p5.reset_index(level=0, inplace=True)
noresm_2080_8p5.columns = ['Precip', 'Temp']

# %% [markdown]
# #### 1.2d) Concatenate dataframes to obtain one record with all climate data for each model

# %%
gfdl_8p5 = pd.concat([gfdl_2000_8p5, gfdl_2020_8p5, gfdl_2040_8p5, gfdl_2060_8p5, gfdl_2080_8p5], axis = 0).astype(float)
hadgem_8p5 = pd.concat([hadgem_2000_8p5, hadgem_2020_8p5, hadgem_2040_8p5, hadgem_2060_8p5, hadgem_2080_8p5], axis = 0).astype(float)
ipsl_8p5 = pd.concat([ipsl_2000_8p5, ipsl_2020_8p5, ipsl_2040_8p5, ipsl_2060_8p5, ipsl_2080_8p5], axis = 0).astype(float)
miroc_8p5 = pd.concat([miroc_2000_8p5, miroc_2020_8p5, miroc_2040_8p5, miroc_2060_8p5, miroc_2080_8p5], axis = 0).astype(float)
noresm_8p5 = pd.concat([noresm_2000_8p5, noresm_2020_8p5, noresm_2040_8p5, noresm_2060_8p5, noresm_2080_8p5], axis = 0).astype(float)

# %% [markdown]
# #### 1.2e) Reshape arrays to get mean annual temperature

# %%
gfdl_temp_8p5 = np.array(gfdl_8p5['Temp'], dtype = float)
gfdl_temp_reshape_8p5 = gfdl_temp_8p5.reshape(120,365)
gfdl_temp_rows_8p5 = np.mean(gfdl_temp_reshape_8p5, axis = 1)

hadgem_temp_8p5 = np.array(hadgem_8p5['Temp'], dtype = float)
hadgem_temp_reshape_8p5 = hadgem_temp_8p5.reshape(120,365)
hadgem_temp_rows_8p5 = np.mean(hadgem_temp_reshape_8p5, axis = 1)

ipsl_temp_8p5 = np.array(ipsl_8p5['Temp'], dtype = float)
ipsl_temp_reshape_8p5 = ipsl_temp_8p5.reshape(120,365)
ipsl_temp_rows_8p5 = np.mean(ipsl_temp_reshape_8p5, axis = 1)

miroc_temp_8p5 = np.array(miroc_8p5['Temp'], dtype = float)
miroc_temp_reshape_8p5 = miroc_temp_8p5.reshape(120,365)
miroc_temp_rows_8p5 = np.mean(miroc_temp_reshape_8p5, axis = 1)

noresm_temp_8p5 = np.array(noresm_8p5['Temp'], dtype = float)
noresm_temp_reshape_8p5 = noresm_temp_8p5.reshape(120,365)
noresm_temp_rows_8p5 = np.mean(noresm_temp_reshape_8p5, axis = 1)

# %% [markdown]
# #### 1.2f) Reshape arrays to get mean annual precipitation

# %%
gfdl_prec_8p5 = np.array(gfdl_8p5['Precip'], dtype = float)
gfdl_prec_reshape_8p5 = gfdl_prec_8p5.reshape(120,365)
gfdl_prec_rows_8p5 = np.mean(gfdl_prec_reshape_8p5, axis = 1)

hadgem_prec_8p5 = np.array(hadgem_8p5['Precip'], dtype = float)
hadgem_prec_reshape_8p5 = hadgem_prec_8p5.reshape(120,365)
hadgem_prec_rows_8p5 = np.mean(hadgem_prec_reshape_8p5, axis = 1)

ipsl_prec_8p5 = np.array(ipsl_8p5['Precip'], dtype = float)
ipsl_prec_reshape_8p5 = ipsl_prec_8p5.reshape(120,365)
ipsl_prec_rows_8p5 = np.mean(ipsl_prec_reshape_8p5, axis = 1)

miroc_prec_8p5 = np.array(miroc_8p5['Precip'], dtype = float)
miroc_prec_reshape_8p5 = miroc_prec_8p5.reshape(120,365)
miroc_prec_rows_8p5 = np.mean(miroc_prec_reshape_8p5, axis = 1)

noresm_prec_8p5 = np.array(noresm_8p5['Precip'], dtype = float)
noresm_prec_reshape_8p5 = noresm_prec_8p5.reshape(120,365)
noresm_prec_rows_8p5 = np.mean(noresm_prec_reshape_8p5, axis = 1)

# %% [markdown]
# ### 1.3. Plot climate data (precipitation and temperature) over the simulation time period for rcp4.5 and rcp8.5 scenarios

# %%
fig, ax = plt.subplots(2,2, sharex = 'col', figsize = [8,6], sharey='row')

ax[0,0].plot(gfdl_temp_rows_4p5, label = 'GFDL-ESM2M', color = 'tab:blue')
ax[0,0].plot(hadgem_temp_rows_4p5, label = 'HadGEM2', color = 'tab:orange')
ax[0,0].plot(ipsl_temp_rows_4p5, label = 'IPSL_CM5A', color = 'tab:green')
ax[0,0].plot(miroc_temp_rows_4p5, label = 'MIROC-ESM-CHEM', color = 'tab:red')
ax[0,0].plot(noresm_temp_rows_4p5, label = 'NORESM-M', color = 'tab:purple')
ax[0,0].legend(loc=2, prop={'size':9})
ax[0,1].plot(gfdl_temp_rows_8p5, label = 'GFDL-ESM2M', color = 'tab:blue')
ax[0,1].plot(hadgem_temp_rows_8p5, label = 'HadGEM2', color = 'tab:orange')
ax[0,1].plot(ipsl_temp_rows_8p5, label = 'IPSL_CM5A', color = 'tab:green')
ax[0,1].plot(miroc_temp_rows_8p5, label = 'MIROC-ESM-CHEM', color = 'tab:red')
ax[0,1].plot(noresm_temp_rows_8p5, label = 'NORESM-M', color = 'tab:purple')

ax[1,0].plot(gfdl_prec_rows_4p5, label = 'GFDL-ESM2M', color = 'tab:blue')
ax[1,0].plot(hadgem_prec_rows_4p5, label = 'HadGEM2', color = 'tab:orange')
ax[1,0].plot(ipsl_prec_rows_4p5, label = 'IPSL_CM5A', color = 'tab:green')
ax[1,0].plot(miroc_prec_rows_4p5, label = 'MIROC-ESM-CHEM', color = 'tab:red')
ax[1,0].plot(noresm_prec_rows_4p5, label = 'NORESM-M', color = 'tab:purple')
ax[1,1].plot(gfdl_prec_rows_8p5, label = 'GFDL-ESM2M', color = 'tab:blue')
ax[1,1].plot(hadgem_prec_rows_8p5, label = 'HadGEM2', color = 'tab:orange')
ax[1,1].plot(ipsl_prec_rows_8p5, label = 'IPSL_CM5A', color = 'tab:green')
ax[1,1].plot(miroc_prec_rows_8p5, label = 'MIROC-ESM-CHEM', color = 'tab:red')
ax[1,1].plot(noresm_prec_rows_8p5, label = 'NORESM-M', color = 'tab:purple')

#ax[1,1].set_xlabel('Year in simulation')
ax[0,0].set_ylabel('Mean Temperature ($^{\circ}$C)', size = 12)
ax[1,0].set_ylabel('Mean Daily Precipitation (mm)', size = 12)
ax[0,0].set_title('RCP4.5', size = 14)
ax[0,1].set_title('RCP8.5', size = 14)

fig.text(0.52, -0.02, 'Year in simulation', ha='center', size = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 2: Calculate mean annual and mean daily temperature and precipitation, then plot results
#
# ### 2.1. Calculate mean annual and mean daily temperature

# %%
gfdl_2000_temp = np.array(gfdl_2000_8p5['Temp'][:-8], dtype = float)
gfdl_2000_temp_reshape = gfdl_2000_temp.reshape(30,365)
gfdl_2000_temp_rows = np.mean(gfdl_2000_temp_reshape, axis = 1)
gfdl_2000_temp_cols = np.mean(gfdl_2000_temp_reshape, axis = 0)

hadgem_2000_temp = np.array(hadgem_2000_8p5['Temp'][:-8], dtype = float)
hadgem_2000_temp_reshape = hadgem_2000_temp.reshape(30,365)
hadgem_2000_temp_rows = np.mean(hadgem_2000_temp_reshape, axis = 1)
hadgem_2000_temp_cols = np.mean(hadgem_2000_temp_reshape, axis = 0)

miroc_2000_temp = np.array(miroc_2000_8p5['Temp'][:-8], dtype = float)
miroc_2000_temp_reshape = miroc_2000_temp.reshape(30,365)
miroc_2000_temp_rows = np.mean(miroc_2000_temp_reshape, axis = 1)
miroc_2000_temp_cols = np.mean(miroc_2000_temp_reshape, axis = 0)

noresm_2000_temp = np.array(noresm_2000_8p5['Temp'][:-8], dtype = float)
noresm_2000_temp_reshape = noresm_2000_temp.reshape(30,365)
noresm_2000_temp_rows = np.mean(noresm_2000_temp_reshape, axis = 1)
noresm_2000_temp_cols = np.mean(noresm_2000_temp_reshape, axis = 0)

# %% [markdown]
# ### 2.2. Calculate mean annual and mean daily precipitation

# %%
gfdl_2000_prec = np.array(gfdl_2000_8p5['Precip'][:-8], dtype = float)
gfdl_2000_prec_reshape = gfdl_2000_prec.reshape(30,365)
gfdl_2000_prec_rows = np.mean(gfdl_2000_prec_reshape, axis = 1)
gfdl_2000_prec_cols = np.mean(gfdl_2000_prec_reshape, axis = 0)

hadgem_2000_prec = np.array(hadgem_2000_8p5['Precip'][:-8], dtype = float)
hadgem_2000_prec_reshape = hadgem_2000_prec.reshape(30,365)
hadgem_2000_prec_rows = np.mean(hadgem_2000_prec_reshape, axis = 1)
hadgem_2000_prec_cols = np.mean(hadgem_2000_prec_reshape, axis = 0)

miroc_2000_prec = np.array(miroc_2000_8p5['Precip'][:-8], dtype = float)
miroc_2000_prec_reshape = miroc_2000_prec.reshape(30,365)
miroc_2000_prec_rows = np.mean(miroc_2000_prec_reshape, axis = 1)
miroc_2000_prec_cols = np.mean(miroc_2000_prec_reshape, axis = 0)

noresm_2000_prec = np.array(noresm_2000_8p5['Precip'][:-8], dtype = float)
noresm_2000_prec_reshape = noresm_2000_prec.reshape(30,365)
noresm_2000_prec_rows = np.mean(noresm_2000_prec_reshape, axis = 1)
noresm_2000_prec_cols = np.mean(noresm_2000_prec_reshape, axis = 0)

# %% [markdown]
# ### 2.3. Plot mean annual and mean daily temperature and precipitation

# %%
fig, ax = plt.subplots(2,2, figsize = [8,6])

ax[0,0].plot(gfdl_2000_temp_rows, label = 'GFDL-ESM2M', color = 'tab:blue')
ax[0,0].plot(hadgem_2000_temp_rows, label = 'HadGEM2', color = 'tab:orange')
ax[0,0].plot(miroc_2000_temp_rows, label = 'MIROC-ESM-CHEM', color = 'tab:red')
ax[0,0].plot(noresm_2000_temp_rows, label = 'NORESM-M', color = 'tab:purple')

ax[0,1].plot(gfdl_2000_temp_cols, color = 'tab:blue')
ax[0,1].plot(hadgem_2000_temp_cols, color = 'tab:orange')
ax[0,1].plot(miroc_2000_temp_cols, color = 'tab:red')
ax[0,1].plot(noresm_2000_temp_cols, color = 'tab:purple')

ax[1,0].plot(gfdl_2000_prec_rows, color = 'tab:blue')
ax[1,0].plot(hadgem_2000_prec_rows, color = 'tab:orange')
ax[1,0].plot(miroc_2000_prec_rows, color = 'tab:red')
ax[1,0].plot(noresm_2000_prec_rows, color = 'tab:purple')

ax[1,1].plot(gfdl_2000_prec_cols, color = 'tab:blue')
ax[1,1].plot(hadgem_2000_prec_cols, color = 'tab:orange')
ax[1,1].plot(miroc_2000_prec_cols, color = 'tab:red')
ax[1,1].plot(noresm_2000_prec_cols, color = 'tab:purple')

ax[0,0].set_ylabel('Mean Annual Temp ($^{\circ}$C)', size = 12)
ax[1,0].set_ylabel('Mean Annual Precip (mm)', size = 12)
ax[0,1].set_ylabel('Mean Daily Temp ($^{\circ}$C)', size = 12)
ax[1,1].set_ylabel('Mean Daily Precip (mm)', size = 12)
ax[1,0].set_xlabel('Year in Simulation', size = 12)
ax[1,1].set_xlabel('Day in Year', size = 12)
fig.legend(loc = 1, prop={'size':8})
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4. Print mean and max annual precipitation and temperature

# %% [markdown]
# #### 2.4a) Mean and max annual precipitation

# %%
print('Mean Annual Precip')
print('GFDL: {:.3}'.format(gfdl_2000_prec_rows.mean()))
print('HadGEM: {:.3}'.format(hadgem_2000_prec_rows.mean()))
print('MIROC: {:.3}'.format(miroc_2000_prec_rows.mean()))
print('NORESM: {:.3}'.format(noresm_2000_prec_rows.mean()))
print()
print('Max Annual Precip')
print('GFDL: {:.3}'.format(gfdl_2000_prec_rows.max()))
print('HadGEM: {:.3}'.format(hadgem_2000_prec_rows.max()))
print('MIROC: {:.3}'.format(miroc_2000_prec_rows.max()))
print('NORESM: {:.3}'.format(noresm_2000_prec_rows.max()))
# Out:
# Mean Annual Precip
# GFDL: 4.63
# HadGEM: 4.53
# MIROC: 4.7
# NORESM: 4.63
#
# Max Annual Precip
# GFDL: 6.64
# HadGEM: 5.13
# MIROC: 5.87
# NORESM: 5.73

# %% [markdown]
# #### 2.4b) Mean and max annual temperature

# %%
print('Mean Annual Temp')
print('GFDL: {:.3}'.format(gfdl_2000_temp_rows.mean()))
print('HadGEM: {:.3}'.format(hadgem_2000_temp_rows.mean()))
print('MIROC: {:.3}'.format(miroc_2000_temp_rows.mean()))
print('NORESM: {:.3}'.format(noresm_2000_temp_rows.mean()))
print()
print('Max Annual Temp')
print('GFDL: {:.3}'.format(gfdl_2000_temp_rows.max()))
print('HadGEM: {:.3}'.format(hadgem_2000_temp_rows.max()))
print('MIROC: {:.3}'.format(miroc_2000_temp_rows.max()))
print('NORESM: {:.3}'.format(noresm_2000_temp_rows.max()))
# Out:
# Mean Annual Temp
# GFDL: 28.8
# HadGEM: 28.7
# MIROC: 28.9
# NORESM: 28.9
#
# Max Annual Temp
# GFDL: 29.7
# HadGEM: 29.5
# MIROC: 29.9
# NORESM: 29.6
