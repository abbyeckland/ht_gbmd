# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import reshape
import os
import collections
import pylab

# %% [markdown]
# ## Contents of notebook:
#
# **Part 1: Load and plot projected water and sediment discharge through 2100**
# - Outputs from each climate model are imported into the notebook
# - Dataframes are cleaned up so to perform calculations
# - Data are reshaped to obtain mean annual water and sediment discharge
# - Data are plotted
#
# **Part 2: Calculate average water and sediment discharge and annual sediment discharge for each time period**
# - Summary statistic csv files are imported into the notebook
# - Averages for water discharge, SSC, sediment discharge, and annual sediment discharge are taken over each climate model to get one value per time period
#
# **Part 3: Compare and contrast sediment discharge values calculated via different methods**
# - Method 1: Sum method
# - Method 2: Sediment rating curve method

# %% [markdown]
# # Part 1: Load and plot projected water and sediment discharge through 2100
#
# ## 1.1. Import ASCII data

# %% [markdown]
# ### 1.1a) GFDL-ESM2M

# %%
gfdl_csv = pd.read_csv('../../setup/run_2/Ganga/rcp4p5/GFDL-ESM2M/ASCII_data_fullrecord_gfdl.csv', dtype=float)
gfdl = pd.DataFrame(gfdl_csv)
gfdl
# Out:
#        Unnamed: 0  Qw(m3/s)  Qs(kg/s)  Qb(kg/s)  CsBin1  CsBin2  CsBin3  \
# 0             0.0   884.000     0.473    18.554     0.0     0.0     0.0
# 1             1.0   884.000     0.151    18.554     0.0     0.0     0.0
# 2             2.0   884.000     0.268    18.554     0.0     0.0     0.0
# 3             3.0   884.000     0.296    18.554     0.0     0.0     0.0
# 4             4.0   884.000     0.362    18.554     0.0     0.0     0.0
# ...           ...       ...       ...       ...     ...     ...     ...
# 43795     43795.0  1429.361     0.750    30.000     NaN     0.0     0.0
# 43796     43796.0  1315.478     0.734    27.610     NaN     0.0     0.0
# 43797     43797.0  1213.931     0.778    25.478     NaN     0.0     0.0
# 43798     43798.0  1133.802     0.516    23.796     NaN     0.0     0.0
# 43799     43799.0  1067.909     0.459    22.414     NaN     0.0     0.0
#
#        CsBin4  vel(m/s)    wid(m)  dep(m)  temp(deg.C)  prec(m)  CsBin 1
# 0         0.0     0.845  1152.078   0.908     19.63034  0.00000      NaN
# 1         0.0     0.845  1152.078   0.908     20.23071  0.00001      NaN
# 2         0.0     0.845  1152.078   0.908     20.35250  0.00002      NaN
# 3         0.0     0.845  1152.078   0.908     19.83328  0.00007      NaN
# 4         0.0     0.845  1152.078   0.908     19.47083  0.00009      NaN
# ...       ...       ...       ...     ...          ...      ...      ...
# 43795     0.0     0.996  1305.393   1.100     19.79612  0.00000      0.0
# 43796     0.0     0.968  1277.515   1.064     20.12319  0.00000      0.0
# 43797     0.0     0.942  1251.108   1.030     20.46266  0.00000      0.0
# 43798     0.0     0.920  1229.091   1.003     20.66034  0.00000      0.0
# 43799     0.0     0.902  1210.106   0.979     20.91053  0.00000      0.0
#
# [43800 rows x 14 columns]

# %% [markdown]
# ### 1.1b) HadGEM2

# %%
hadgem_csv = pd.read_csv('../../setup/run_2/Ganga/rcp4p5/HadGEM2/ASCII_data_fullrecord_hadgem.csv', dtype=float)
hadgem = pd.DataFrame(hadgem_csv)
hadgem
# Out:
#        Unnamed: 0  Qw(m3/s)  Qs(kg/s)  Qb(kg/s)  CsBin1  CsBin2  CsBin3  \
# 0             0.0     884.0     0.178    18.554     0.0     0.0     0.0
# 1             1.0     884.0     0.057    18.554     0.0     0.0     0.0
# 2             2.0     884.0     0.100    18.554     0.0     0.0     0.0
# 3             3.0     884.0     0.111    18.554     0.0     0.0     0.0
# 4             4.0     884.0     0.136    18.554     0.0     0.0     0.0
# ...           ...       ...       ...       ...     ...     ...     ...
# 43795     43795.0     884.0     0.023    18.554     NaN     0.0     0.0
# 43796     43796.0     884.0     0.019    18.554     NaN     0.0     0.0
# 43797     43797.0     884.0     0.012    18.554     NaN     0.0     0.0
# 43798     43798.0     884.0     0.012    18.554     NaN     0.0     0.0
# 43799     43799.0     884.0     0.017    18.554     NaN     0.0     0.0
#
#        CsBin4  vel(m/s)    wid(m)  dep(m)  temp(deg.C)  prec(m)  CsBin 1
# 0         0.0     0.845  1152.078   0.908     21.58135  0.00118      NaN
# 1         0.0     0.845  1152.078   0.908     21.22631  0.00033      NaN
# 2         0.0     0.845  1152.078   0.908     21.32312  0.00006      NaN
# 3         0.0     0.845  1152.078   0.908     21.30432  0.00394      NaN
# 4         0.0     0.845  1152.078   0.908     20.96457  0.00219      NaN
# ...       ...       ...       ...     ...          ...      ...      ...
# 43795     0.0     0.845  1152.078   0.908     20.75236  0.00003      0.0
# 43796     0.0     0.845  1152.078   0.908     20.81139  0.00005      0.0
# 43797     0.0     0.845  1152.078   0.908     20.66030  0.00005      0.0
# 43798     0.0     0.845  1152.078   0.908     20.92964  0.00006      0.0
# 43799     0.0     0.845  1152.078   0.908     21.18457  0.00006      0.0
#
# [43800 rows x 14 columns]

# %% [markdown]
# ### 1.1c) IPSL_CM5A

# %%
ipsl_csv = pd.read_csv('../../setup/run_2/Ganga/rcp4p5/IPSL_CM5A/ASCII_data_fullrecord_ipsl.csv', dtype=float)
ipsl = pd.DataFrame(ipsl_csv)
ipsl
# Out:
#        Unnamed: 0  Qw(m3/s)  Qs(kg/s)  Qb(kg/s)  CsBin1  CsBin2  CsBin3  \
# 0             0.0   884.000     0.045    18.554     0.0     0.0     0.0
# 1             1.0   884.000     0.016    18.554     0.0     0.0     0.0
# 2             2.0   884.000     0.027    18.554     0.0     0.0     0.0
# 3             3.0   884.000     0.029    18.554     0.0     0.0     0.0
# 4             4.0   884.000     0.035    18.554     0.0     0.0     0.0
# ...           ...       ...       ...       ...     ...     ...     ...
# 43795     43795.0   884.056     0.010    18.555     NaN     0.0     0.0
# 43796     43796.0   884.044     0.013    18.555     NaN     0.0     0.0
# 43797     43797.0   884.025     0.019    18.554     NaN     0.0     0.0
# 43798     43798.0   884.008     0.010    18.554     NaN     0.0     0.0
# 43799     43799.0   884.008     0.013    18.554     NaN     0.0     0.0
#
#        CsBin4  vel(m/s)    wid(m)  dep(m)  temp(deg.C)  prec(m)  CsBin 1
# 0         0.0     0.845  1152.078   0.908     15.84762  0.00000      NaN
# 1         0.0     0.845  1152.078   0.908     17.39624  0.00000      NaN
# 2         0.0     0.845  1152.078   0.908     17.86173  0.00000      NaN
# 3         0.0     0.845  1152.078   0.908     18.25805  0.00000      NaN
# 4         0.0     0.845  1152.078   0.908     18.74809  0.00000      NaN
# ...       ...       ...       ...     ...          ...      ...      ...
# 43795     0.0     0.846  1152.097   0.908     21.14965  0.00003      0.0
# 43796     0.0     0.845  1152.093   0.908     21.41078  0.00005      0.0
# 43797     0.0     0.845  1152.087   0.908     21.41618  0.00005      0.0
# 43798     0.0     0.845  1152.081   0.908     22.13623  0.00032      0.0
# 43799     0.0     0.845  1152.081   0.908     22.80981  0.00563      0.0
#
# [43800 rows x 14 columns]

# %% [markdown]
# ### 1.1d) MIROC-ESM-CHEM

# %%
miroc_csv = pd.read_csv('../../setup/run_2/Ganga/rcp4p5/MIROC-ESM-CHEM/ASCII_data_fullrecord_miroc.csv', dtype=float)
miroc = pd.DataFrame(miroc_csv)
#miroc.drop(['Unnamed: 0','index', 'index.1', 'index.2', 'index.3', 'index.4', 'index.5'], axis = 1)
miroc
# Out:
#        Unnamed: 0  Qw(m3/s)  Qs(kg/s)  Qb(kg/s)  CsBin1  CsBin2  CsBin3  \
# 0             0.0     884.0     0.945    18.554     0.0     0.0     0.0
# 1             1.0     884.0     0.273    18.554     0.0     0.0     0.0
# 2             2.0     884.0     0.508    18.554     0.0     0.0     0.0
# 3             3.0     884.0     0.567    18.554     0.0     0.0     0.0
# 4             4.0     884.0     0.706    18.554     0.0     0.0     0.0
# ...           ...       ...       ...       ...     ...     ...     ...
# 43795     43795.0     884.0     0.221    18.554     NaN     0.0     0.0
# 43796     43796.0     884.0     0.166    18.554     NaN     0.0     0.0
# 43797     43797.0     884.0     0.094    18.554     NaN     0.0     0.0
# 43798     43798.0     884.0     0.093    18.554     NaN     0.0     0.0
# 43799     43799.0     884.0     0.153    18.554     NaN     0.0     0.0
#
#        CsBin4  vel(m/s)    wid(m)  dep(m)  temp(deg.C)  prec(m)  CsBin 1
# 0         0.0     0.845  1152.078   0.908     19.03946  0.00458      NaN
# 1         0.0     0.845  1152.078   0.908     18.80338  0.00417      NaN
# 2         0.0     0.845  1152.078   0.908     17.89518  0.00444      NaN
# 3         0.0     0.845  1152.078   0.908     18.30454  0.00044      NaN
# 4         0.0     0.845  1152.078   0.908     18.44487  0.00000      NaN
# ...       ...       ...       ...     ...          ...      ...      ...
# 43795     0.0     0.845  1152.078   0.908     21.83937  0.00017      0.0
# 43796     0.0     0.845  1152.078   0.908     21.68050  0.00000      0.0
# 43797     0.0     0.845  1152.078   0.908     21.84815  0.00000      0.0
# 43798     0.0     0.845  1152.078   0.908     22.07008  0.00006      0.0
# 43799     0.0     0.845  1152.078   0.908     21.70774  0.00000      0.0
#
# [43800 rows x 14 columns]

# %% [markdown]
# ### 1.1e) NORESM-M

# %%
noresm_csv = pd.read_csv('../../setup/run_2/Ganga/rcp4p5/NORESM-M/ASCII_data_fullrecord_noresm.csv', dtype=float)
noresm = pd.DataFrame(noresm_csv)
noresm
# Out:
#        Unnamed: 0  Qw(m3/s)  Qs(kg/s)  Qb(kg/s)  CsBin1  CsBin2  CsBin3  \
# 0             0.0   884.000     0.586    18.554     0.0     0.0     0.0
# 1             1.0   884.000     0.180    18.554     0.0     0.0     0.0
# 2             2.0   884.000     0.325    18.554     0.0     0.0     0.0
# 3             3.0   884.000     0.360    18.554     0.0     0.0     0.0
# 4             4.0   884.000     0.444    18.554     0.0     0.0     0.0
# ...           ...       ...       ...       ...     ...     ...     ...
# 43795     43795.0   884.130     0.057    18.556     NaN     0.0     0.0
# 43796     43796.0   884.114     0.045    18.556     NaN     0.0     0.0
# 43797     43797.0   884.101     0.029    18.556     NaN     0.0     0.0
# 43798     43798.0   884.087     0.028    18.555     NaN     0.0     0.0
# 43799     43799.0   884.073     0.042    18.555     NaN     0.0     0.0
#
#        CsBin4  vel(m/s)    wid(m)  dep(m)  temp(deg.C)  prec(m)  CsBin 1
# 0         0.0     0.845  1152.078   0.908     17.49028  0.00001      NaN
# 1         0.0     0.845  1152.078   0.908     16.48946  0.00000      NaN
# 2         0.0     0.845  1152.078   0.908     16.29749  0.00000      NaN
# 3         0.0     0.845  1152.078   0.908     16.11992  0.00000      NaN
# 4         0.0     0.845  1152.078   0.908     15.92834  0.00002      NaN
# ...       ...       ...       ...     ...          ...      ...      ...
# 43795     0.0     0.846  1152.122   0.908     18.27269  0.00000      0.0
# 43796     0.0     0.846  1152.117   0.908     18.69951  0.00000      0.0
# 43797     0.0     0.846  1152.112   0.908     18.67046  0.00000      0.0
# 43798     0.0     0.846  1152.108   0.908     18.71818  0.00000      0.0
# 43799     0.0     0.846  1152.103   0.908     19.09936  0.00000      0.0
#
# [43800 rows x 14 columns]

# %% [markdown]
# ## 1.2. Reshape Qw arrays

# %%
# 90 rows by 365 columns = 90 years of output data
gfdl_qw = np.array(gfdl['Qw(m3/s)'])
gfdl_qw_reshape = gfdl_qw.reshape(120,365)
gfdl_qw_mean_rows = np.mean(gfdl_qw_reshape, axis = 1)

hadgem_qw = np.array(hadgem['Qw(m3/s)'])
hadgem_qw_reshape = hadgem_qw.reshape(120,365)
hadgem_qw_mean_rows = np.mean(hadgem_qw_reshape, axis = 1)

ipsl_qw = np.array(ipsl['Qw(m3/s)'])
ipsl_qw_reshape = ipsl_qw.reshape(120,365)
ipsl_qw_mean_rows = np.mean(ipsl_qw_reshape, axis = 1)

miroc_qw = np.array(miroc['Qw(m3/s)'])
miroc_qw_reshape = miroc_qw.reshape(120,365)
miroc_qw_mean_rows = np.mean(miroc_qw_reshape, axis = 1)

noresm_qw = np.array(noresm['Qw(m3/s)'])
noresm_qw_reshape = noresm_qw.reshape(120,365)
noresm_qw_mean_rows = np.mean(noresm_qw_reshape, axis = 1)

# %% [markdown]
# ## 1.3. Plot Qw outputs
#
# ### 1.3a) Color plot with NO trendline

# %%
years = np.arange(1, 121, 1)

fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qw_mean_rows, color = 'tab:blue', label = 'GFDL-ESM2M')
plt.plot(years, hadgem_qw_mean_rows, color = 'tab:orange', label = 'HadGEM2')
plt.plot(years, ipsl_qw_mean_rows, color = 'tab:green', label = 'IPSL_CM5A')
plt.plot(years, miroc_qw_mean_rows, color = 'tab:red', label = 'MIROC-ESM-CHEM')
plt.plot(years, noresm_qw_mean_rows, color = 'tab:purple', label = 'NORESM-M')
plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Discharge (m$^3/$s)', size = 14)
plt.title('Ganges Projected Water Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.tight_layout()
fig.savefig('../../figures/v2/projections/ganga_qw_rcp4p5_notrend_color.png')

# %% [markdown]
# ### 1.3b) Calculate trendlines

# %%
# calc the trendline for gfdl
z_gfdl = np.polyfit(years, gfdl_qw_mean_rows, 1)
p_gfdl = np.poly1d(z_gfdl)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_gfdl[0],z_gfdl[1]), '(GFDL-ESM2M)')

# calc the trendline for hadgem
z_hadgem = np.polyfit(years, hadgem_qw_mean_rows, 1)
p_hadgem = np.poly1d(z_hadgem)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_hadgem[0],z_hadgem[1]), '(HadGEM2)')

# calc the trendline for ipsl
z_ipsl = np.polyfit(years, ipsl_qw_mean_rows, 1)
p_ipsl = np.poly1d(z_ipsl)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_ipsl[0],z_ipsl[1]), '(IPSL_CM5A)')

# calc the trendline for miroc
z_miroc = np.polyfit(years, miroc_qw_mean_rows, 1)
p_miroc = np.poly1d(z_miroc)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_miroc[0],z_miroc[1]), '(MIROC-ESM-CHEM)')

# calc the trendline for noresm
z_noresm = np.polyfit(years, noresm_qw_mean_rows, 1)
p_noresm = np.poly1d(z_noresm)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_noresm[0],z_noresm[1]), '(NORESM-M)')
# Out:
# y=0.134002x+(12462.114731) (GFDL-ESM2M)
# y=81.441456x+(12309.872030) (HadGEM2)
# y=81.074337x+(12669.485235) (IPSL_CM5A)
# y=34.324085x+(10426.047332) (MIROC-ESM-CHEM)
# y=66.142079x+(11780.081052) (NORESM-M)

# %% [markdown]
# ### 1.3c) Color plot WITH trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))

plt.plot(years, gfdl_qw_mean_rows, color = 'tab:blue', label = 'GFDL-ESM2M')
pylab.plot(years,p_gfdl(years), color = 'tab:blue', linestyle = 'dashed')

plt.plot(years, hadgem_qw_mean_rows, color = 'tab:orange', label = 'HadGEM2')
pylab.plot(years,p_hadgem(years), color = 'tab:orange', linestyle = 'dashed' )

plt.plot(years, ipsl_qw_mean_rows, color = 'tab:green', label = 'IPSL_CM5A')
pylab.plot(years,p_ipsl(years), color = 'tab:green', linestyle = 'dashed')

plt.plot(years, miroc_qw_mean_rows, color = 'tab:red', label = 'MIROC-ESM-CHEM')
pylab.plot(years,p_miroc(years), color = 'tab:red', linestyle = 'dashed')

plt.plot(years, noresm_qw_mean_rows, color = 'tab:purple', label = 'NORESM-M')
pylab.plot(years,p_noresm(years), color = 'tab:purple', linestyle = 'dashed')

plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Discharge (m$^3/$s)', size = 14)
plt.title('Ganges Projected Water Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.tight_layout()
fig.savefig('../../figures/v2/projections/ganga_qw_rcp4p5_trend_color.png')

# %% [markdown]
# ### 1.3d) B&W plot NO trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qw_mean_rows, color = 'black', label = 'GFDL-ESM2M')
plt.plot(years, hadgem_qw_mean_rows, color = 'dimgray', label = 'HadGEM2')
plt.plot(years, ipsl_qw_mean_rows, color = 'gray', label = 'IPSL_CM5A')
plt.plot(years, miroc_qw_mean_rows, color = 'darkgray', label = 'MIROC-ESM-CHEM')
plt.plot(years, noresm_qw_mean_rows, color = 'silver', label = 'NORESM-M')
plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Discharge (m$^3/$s)', size = 14)
plt.title('Ganges Projected Water Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.tight_layout()
fig.savefig('../../figures/v2/projections/ganga_qw_rcp4p5_notrend_bw.png')

# %% [markdown]
# ### 1.3e) B&W plot WITH trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qw_mean_rows, color = 'black', label = 'GFDL-ESM2M')
pylab.plot(years,p_gfdl(years), color = 'black', linestyle = 'dashed')

plt.plot(years, hadgem_qw_mean_rows, color = 'dimgray', label = 'HadGEM2')
pylab.plot(years,p_hadgem(years), color = 'dimgray', linestyle = 'dashed' )

plt.plot(years, ipsl_qw_mean_rows, color = 'gray', label = 'IPSL_CM5A')
pylab.plot(years,p_ipsl(years), color = 'gray', linestyle = 'dashed')

plt.plot(years, miroc_qw_mean_rows, color = 'darkgray', label = 'MIROC-ESM-CHEM')
pylab.plot(years,p_miroc(years), color = 'darkgray', linestyle = 'dashed')

plt.plot(years, noresm_qw_mean_rows, color = 'silver', label = 'NORESM-M')
pylab.plot(years,p_noresm(years), color = 'silver', linestyle = 'dashed')

plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Discharge (m$^3/$s)', size = 14)
plt.title('Ganges Projected Water Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.savefig('../../figures/v2/projections/ganga_qw_rcp4p5_trend_bw.png')

# %% [markdown]
# ## 1.4. Reshape Qs arrays

# %%
# 90 rows by 365 columns = 90 years of output data
gfdl_qs = np.array(gfdl['Qs(kg/s)'])
gfdl_qs_reshape = gfdl_qs.reshape(120,365)
gfdl_qs_mean_rows = np.mean(gfdl_qs_reshape, axis = 1)

hadgem_qs = np.array(hadgem['Qs(kg/s)'])
hadgem_qs_reshape = hadgem_qs.reshape(120,365)
hadgem_qs_mean_rows = np.mean(hadgem_qs_reshape, axis = 1)

ipsl_qs = np.array(ipsl['Qs(kg/s)'])
ipsl_qs_reshape = ipsl_qs.reshape(120,365)
ipsl_qs_mean_rows = np.mean(ipsl_qs_reshape, axis = 1)

miroc_qs = np.array(miroc['Qs(kg/s)'])
miroc_qs_reshape = miroc_qs.reshape(120,365)
miroc_qs_mean_rows = np.mean(miroc_qs_reshape, axis = 1)

noresm_qs = np.array(noresm['Qs(kg/s)'])
noresm_qs_reshape = noresm_qs.reshape(120,365)
noresm_qs_mean_rows = np.mean(noresm_qs_reshape, axis = 1)

# %% [markdown]
# ## 1.5. Plot Qs outputs
#
# ### 1.5a) Color plot with NO trendline

# %%
fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qs_mean_rows, color = 'tab:blue', label = 'GFDL-ESM2M')
plt.plot(years, hadgem_qs_mean_rows, color = 'tab:orange', label = 'HadGEM2')
plt.plot(years, ipsl_qs_mean_rows, color = 'tab:green', label = 'IPSL_CM5A')
plt.plot(years, miroc_qs_mean_rows, color = 'tab:red', label = 'MIROC-ESM-CHEM')
plt.plot(years, noresm_qs_mean_rows, color = 'tab:purple', label = 'NORESM-M')
plt.xlabel('Year in simulation', size = 14)
plt.ylim(0,2e5)
plt.ylabel('Sediment Discharge (kg/s)', size = 14)
plt.title('Ganges Projected Sediment Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.tight_layout()
fig.savefig('../../figures/v2/projections/ganga_qs_rcp4p5_notrend_color.png')

# %% [markdown]
# ### 1.5b) Calculate trendlines

# %%
# calc the trendline for gfdl
z_gfdl = np.polyfit(years, gfdl_qs_mean_rows, 1)
p_gfdl = np.poly1d(z_gfdl)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_gfdl[0],z_gfdl[1]), '(GFDL-ESM2M)')

# calc the trendline for hadgem
z_hadgem = np.polyfit(years, hadgem_qs_mean_rows, 1)
p_hadgem = np.poly1d(z_hadgem)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_hadgem[0],z_hadgem[1]), '(HadGEM2)')

# calc the trendline for ipsl
z_ipsl = np.polyfit(years, ipsl_qs_mean_rows, 1)
p_ipsl = np.poly1d(z_ipsl)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_ipsl[0],z_ipsl[1]), '(IPSL_CM5A)')

# calc the trendline for miroc
z_miroc = np.polyfit(years, miroc_qs_mean_rows, 1)
p_miroc = np.poly1d(z_miroc)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_miroc[0],z_miroc[1]), '(MIROC-ESM-CHEM)')

# calc the trendline for noresm
z_noresm = np.polyfit(years, noresm_qs_mean_rows, 1)
p_noresm = np.poly1d(z_noresm)
# the line equation:
print("y=%.6fx+(%.6f)"%(z_noresm[0],z_noresm[1]), '(NORESM-M)')
# Out:
# y=27.016313x+(22838.919101) (GFDL-ESM2M)
# y=95.895240x+(18586.278509) (HadGEM2)
# y=72.895544x+(21831.780924) (IPSL_CM5A)
# y=71.890410x+(20060.807098) (MIROC-ESM-CHEM)
# y=74.598298x+(20361.162264) (NORESM-M)

# %% [markdown]
# ### 1.5c) Color plot WITH trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))

plt.plot(years, gfdl_qs_mean_rows, color = 'tab:blue', label = 'GFDL-ESM2M')
pylab.plot(years,p_gfdl(years), color = 'tab:blue', linestyle = 'dashed')

plt.plot(years, hadgem_qs_mean_rows, color = 'tab:orange', label = 'HadGEM2')
pylab.plot(years,p_hadgem(years), color = 'tab:orange', linestyle = 'dashed' )

plt.plot(years, ipsl_qs_mean_rows, color = 'tab:green', label = 'IPSL_CM5A')
pylab.plot(years,p_ipsl(years), color = 'tab:green', linestyle = 'dashed')

plt.plot(years, miroc_qs_mean_rows, color = 'tab:red', label = 'MIROC-ESM-CHEM')
pylab.plot(years,p_miroc(years), color = 'tab:red', linestyle = 'dashed')

plt.plot(years, noresm_qs_mean_rows, color = 'tab:purple', label = 'NORESM-M')
pylab.plot(years,p_noresm(years), color = 'tab:purple', linestyle = 'dashed')

plt.ylim(0,2e5)
plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Sediment Discharge (kg/s)', size = 14)
plt.title('Ganges Projected Sediment Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.tight_layout()
fig.savefig('../../figures/v2/projections/ganga_qs_rcp4p5_trend_color.png')

# %% [markdown]
# ### 1.5d) B&W plot NO trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qs_mean_rows, color = 'black', label = 'GFDL-ESM2M')
plt.plot(years, hadgem_qs_mean_rows, color = 'dimgray', label = 'HadGEM2')
plt.plot(years, ipsl_qs_mean_rows, color = 'gray', label = 'IPSL_CM5A')
plt.plot(years, miroc_qs_mean_rows, color = 'darkgray', label = 'MIROC-ESM-CHEM')
plt.plot(years, noresm_qs_mean_rows, color = 'silver', label = 'NORESM-M')
plt.ylim(0, 2e5)
plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Sediment Discharge (kg/s)', size = 14)
plt.title('Ganges Projected Sediment Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.savefig('../../figures/v2/projections/ganga_qs_rcp4p5_notrend_bw.png')

# %% [markdown]
# ### 1.5e) B&W plot WITH trendlines

# %%
fig, axs = plt.subplots(figsize = (12, 8))
plt.plot(years, gfdl_qs_mean_rows, color = 'black', label = 'GFDL-ESM2M')
pylab.plot(years,p_gfdl(years), color = 'black', linestyle = 'dashed')

plt.plot(years, hadgem_qs_mean_rows, color = 'dimgray', label = 'HadGEM2')
pylab.plot(years,p_hadgem(years), color = 'dimgray', linestyle = 'dashed' )

#plt.plot(years, ipsl_qs_mean_rows, color = 'gray', label = 'IPSL_CM5A')
#pylab.plot(years,p_ipsl(years), color = 'gray', linestyle = 'dashed')

plt.plot(years, miroc_qs_mean_rows, color = 'darkgray', label = 'MIROC-ESM-CHEM')
pylab.plot(years,p_miroc(years), color = 'darkgray', linestyle = 'dashed')

plt.plot(years, noresm_qs_mean_rows, color = 'silver', label = 'NORESM-M')
pylab.plot(years,p_noresm(years), color = 'silver', linestyle = 'dashed')

plt.ylim(0, 2e5)
plt.xlabel('Year in simulation', size = 14)
plt.ylabel('Sediment Discharge (kg/s)', size = 14)
plt.title('Ganges Projected Sediment Discharge: rcp4p5', size = 16)
plt.legend()
plt.show()

fig.savefig('../../figures/v2/projections/ganga_qs_rcp4p5_trend_bw.png')

# %% [markdown]
# # Part 2: Calculate average water and sediment discharge and annual sediment discharge for each time period
#
# ## 2.1. Import Summary Statistics

# %% [markdown]
# ### 2.1a) GFDL-ESM2M

# %%
gfdl_2000 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/reference/GFDL-ESM2M/summ_stats_v3.csv', dtype=float))
gfdl_2020 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/GFDL-ESM2M/2020/summ_stats_v3.csv', dtype=float))
gfdl_2040 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/GFDL-ESM2M/2040/summ_stats_v3.csv', dtype=float))
gfdl_2060 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/GFDL-ESM2M/2060/summ_stats_v3.csv', dtype=float))
gfdl_2080 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/GFDL-ESM2M/2080/summ_stats_v3.csv', dtype=float))

frames_gfdl = [gfdl_2000, gfdl_2020, gfdl_2040, gfdl_2060, gfdl_2080]
concat_gfdl = pd.concat(frames_gfdl)
concat_gfdl.insert(0, 'Time Frame', ['2000', '2020', '2040', '2060', '2080'])

# %%
gfdl_change = ((gfdl_2080 - gfdl_2000)/gfdl_2000)*100
concat_gfdl = concat_gfdl.append(gfdl_change)
concat_gfdl.round(5)
# Out:
#   Time Frame      Mean Qw      Mean Qs  Mean SSC    Mean Qb        Max Qw  \
# 0       2000  13017.69804  22684.61032   0.39387  273.21814  123409.00592
# 0       2020  11783.38844  22818.03347   0.38468  247.31220  170405.64287
# 0       2040  11586.67595  22982.58095   0.40871  243.18356  170172.19675
# 0       2060  12648.70889  24476.12817   0.38075  265.47372  122745.51075
# 0       2080  12979.15432  24979.23294   0.36164  272.40918  145846.07510
# 0        NaN     -0.29609     10.11533  -8.18111   -0.29609      18.18106
#
#          Max Qs   Max SSC      Max Qb        SD Qw  ...  Qw 50 %ile  \
# 0  3.043041e+06  31.75275  2590.13378  20544.22617  ...  1848.46506
# 0  5.639858e+06  50.60334  3576.50894  19753.41603  ...  1788.68206
# 0  3.352084e+06  40.77553  3571.60932  19262.68158  ...  1941.94877
# 0  4.924965e+06  40.12338  2576.20821  20870.22582  ...  1852.94359
# 0  5.861400e+06  44.22158  3061.04764  21610.09927  ...  2069.38865
# 0  9.261651e+01  39.26849    18.18106      5.18819  ...    11.95173
#
#    Qs 50 %ile  SSC 50 %ile  QB 50 %ile   Qw 90 %ile   Qs 90 %ile  SSC 90 %ile  \
# 0    16.66089      0.01056    38.79597  46181.21683  45710.13590      0.96173
# 0    15.68231      0.01077    37.54123  40931.12757  36935.35164      0.90612
# 0    21.81788      0.01370    40.75802  38735.31454  39100.93271      0.97386
# 0    15.91211      0.01037    38.88996  45443.61257  40396.32507      0.86637
# 0    16.92650      0.01028    43.43276  47027.46754  39904.62574      0.81438
# 0     1.59420     -2.67337    11.95173      1.83246    -12.70071    -15.32142
#
#    QB 90 %ile  DOY Peak Qw  DOY Peak Qs
# 0   969.26095    220.00000    217.00000
# 0   859.07099    195.00000    206.00000
# 0   812.98481    212.00000    220.00000
# 0   953.77996    242.00000    250.00000
# 0   987.02223    214.00000    196.00000
# 0     1.83246     -2.72727     -9.67742
#
# [6 rows x 31 columns]

# %% [markdown]
# ### 2.1b) HadGEM2

# %%
hadgem_2000 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/reference/HadGEM2/summ_stats_v3.csv', dtype=float))
hadgem_2020 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/HadGEM2/2020/summ_stats_v3.csv', dtype=float))
hadgem_2040 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/HadGEM2/2040/summ_stats_v3.csv', dtype=float))
hadgem_2060 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/HadGEM2/2060/summ_stats_v3.csv', dtype=float))
hadgem_2080 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/HadGEM2/2080/summ_stats_v3.csv', dtype=float))

frames_hadgem = [hadgem_2000, hadgem_2020, hadgem_2040, hadgem_2060, hadgem_2080]
concat_hadgem = pd.concat(frames_hadgem)
concat_hadgem.insert(0, 'Time Frame', ['2000', '2020', '2040', '2060', '2080'])

# %%
hadgem_change = ((hadgem_2080 - hadgem_2000)/hadgem_2000)*100
concat_hadgem = concat_hadgem.append(hadgem_change)
concat_hadgem.round(5)
# Out:
#   Time Frame      Mean Qw      Mean Qs  Mean SSC    Mean Qb        Max Qw  \
# 0       2000  12923.84757  22445.04792   0.21689  271.24839  245588.56054
# 0       2020  17622.08850  26980.00659   0.23453  369.85604  286959.90553
# 0       2040  18804.02344  28668.65789   0.25994  394.66274  287909.56197
# 0       2060  18938.07358  29995.43618   0.18418  397.47621  331272.84825
# 0       2080  20619.67603  32105.02029   0.27710  432.77003  332462.68263
# 0        NaN     59.54750     43.03832  27.75856   59.54750      35.37385
#
#          Max Qs   Max SSC      Max Qb        SD Qw  ...  Qw 50 %ile  \
# 0  6.467623e+06  26.61678  5154.46359  27723.75624  ...  1178.05960
# 0  6.620188e+06  36.61505  6022.77395  33721.92523  ...  1415.17348
# 0  6.244148e+06  36.76411  6042.70554  35209.43824  ...  1436.26589
# 0  2.842770e+07  86.96552  6952.82317  36666.41015  ...  1548.82011
# 0  3.236259e+06  21.23168  6977.79566  38799.00242  ...  1556.20130
# 0 -4.996216e+01 -20.23196    35.37385     39.94858  ...    32.09869
#
#    Qs 50 %ile  SSC 50 %ile  QB 50 %ile   Qw 90 %ile   Qs 90 %ile  SSC 90 %ile  \
# 0     2.31913      0.00209    24.72536  45393.76494  16129.21611      0.35205
# 0     2.57525      0.00198    29.70195  64713.91143  23682.88167      0.33462
# 0     3.54925      0.00271    30.14465  71902.87574  37848.71974      0.51630
# 0     2.03005      0.00142    32.50696  71221.28524  17650.58826      0.22684
# 0     4.36370      0.00293    32.66188  77543.76028  38553.76445      0.50669
# 0    88.16085     40.12890    32.09869     70.82469    139.03061     43.92705
#
#    QB 90 %ile  DOY Peak Qw  DOY Peak Qs
# 0   952.73374    227.00000    189.00000
# 0  1358.22898    256.00000    256.00000
# 0  1509.11245    217.00000    261.00000
# 0  1494.80709    221.00000    188.00000
# 0  1627.50451    229.00000    228.00000
# 0    70.82469      0.88106     20.63492
#
# [6 rows x 31 columns]

# %% [markdown]
# ### 2.1c) IPSL_CM5A

# %%
ipsl_2000 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/reference/IPSL_CM5A/summ_stats_v3.csv', dtype=float))
ipsl_2020 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/IPSL_CM5A/2020/summ_stats_v3.csv', dtype=float))
ipsl_2040 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/IPSL_CM5A/2040/summ_stats_v3.csv', dtype=float))
ipsl_2060 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/IPSL_CM5A/2060/summ_stats_v3.csv', dtype=float))
ipsl_2080 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/IPSL_CM5A/2080/summ_stats_v3.csv', dtype=float))

frames_ipsl = [ipsl_2000, ipsl_2020, ipsl_2040, ipsl_2060, ipsl_2080]
concat_ipsl = pd.concat(frames_ipsl)
concat_ipsl.insert(0, 'Time Frame', ['2000', '2020', '2040', '2060', '2080'])

# %%
ipsl_change = ((ipsl_2080 - ipsl_2000)/ipsl_2000)*100
concat_ipsl = concat_ipsl.append(ipsl_change)
concat_ipsl.round(5)
# Out:
#   Time Frame      Mean Qw      Mean Qs  Mean SSC    Mean Qb        Max Qw  \
# 0       2000  14399.11618  24019.70993   0.12324  302.21163  391012.67916
# 0       2020  15318.75554  25927.91288   0.16176  321.51322  424445.21491
# 0       2040  17060.28058  28296.25808   0.16604  358.06470  427056.76577
# 0       2060  21737.36048  32758.63851   0.17742  456.22823  355181.07668
# 0       2080  21826.33829  33447.96111   0.24301  458.09571  378835.23089
# 0        NaN     51.58110     39.25214  97.18317   51.58110      -3.11434
#
#          Max Qs   Max SSC      Max Qb        SD Qw  ...  Qw 50 %ile  \
# 0  2.118525e+07  60.67803  8206.65512  36428.18037  ...  1766.73375
# 0  1.018344e+07  39.71474  8908.34411  33425.23903  ...  1789.87499
# 0  2.649705e+07  71.91483  8963.15588  36440.26477  ...  1834.81118
# 0  1.516733e+07  46.53733  7454.61402  43685.16853  ...  2042.77630
# 0  1.328385e+07  60.04517  7951.07231  44389.29502  ...  2084.60870
# 0 -3.729671e+01  -1.04298    -3.11434     21.85427  ...    17.99224
#
#    Qs 50 %ile  SSC 50 %ile  QB 50 %ile   Qw 90 %ile   Qs 90 %ile  SSC 90 %ile  \
# 0     1.69385      0.00109    37.08057  43057.15231   4912.07258      0.10831
# 0     2.77532      0.00180    37.56627  50442.27715   8849.00054      0.17628
# 0     2.71612      0.00166    38.50940  63416.68045  14691.66090      0.22112
# 0     2.90189      0.00164    42.87421  78554.98357  18742.11641      0.22042
# 0     7.05874      0.00364    43.75220  79619.56298  32637.57342      0.38663
# 0   316.72792    232.86326    17.99224     84.91600    564.43590    256.97954
#
#    QB 90 %ile  DOY Peak Qw  DOY Peak Qs
# 0   903.69243        216.0    217.00000
# 0  1058.69296        217.0    215.00000
# 0  1331.00243        216.0    217.00000
# 0  1648.72827        218.0    219.00000
# 0  1671.07188        216.0    226.00000
# 0    84.91600          0.0      4.14747
#
# [6 rows x 31 columns]

# %% [markdown]
# ### 2.1d) MIROC-ESM-CHEM

# %%
miroc_2000 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/reference/MIROC-ESM-CHEM/summ_stats_v3.csv', dtype=float))
miroc_2020 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/MIROC-ESM-CHEM/2020/summ_stats_v3.csv', dtype=float))
miroc_2040 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/MIROC-ESM-CHEM/2040/summ_stats_v3.csv', dtype=float))
miroc_2060 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/MIROC-ESM-CHEM/2060/summ_stats_v3.csv', dtype=float))
miroc_2080 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/MIROC-ESM-CHEM/2080/summ_stats_v3.csv', dtype=float))

frames_miroc = [miroc_2000, miroc_2020, miroc_2040, miroc_2060, miroc_2080]
concat_miroc = pd.concat(frames_miroc)
concat_miroc.insert(0, 'Time Frame', ['2000', '2020', '2040', '2060', '2080'])

# %%
miroc_change = ((miroc_2080 - miroc_2000)/miroc_2000)*100
concat_miroc = concat_miroc.append(miroc_change)
concat_miroc.round(5)
# Out:
#   Time Frame      Mean Qw      Mean Qs  Mean SSC    Mean Qb        Max Qw  \
# 0       2000  11315.39171  21251.52567   0.42238  237.48979  109562.83023
# 0       2020  11450.01509  22321.74788   0.44165  240.31529  101321.04395
# 0       2040  12269.70632  23400.11549   0.37403  257.51914  148434.92068
# 0       2060  13686.15463  25517.06982   0.37222  287.24785  164070.19215
# 0       2080  14303.90639  26468.59755   0.38548  300.21335  168658.87585
# 0        NaN     26.41106     24.54916  -8.73584   26.41106      53.93804
#
#          Max Qs   Max SSC      Max Qb        SD Qw  ...  Qw 50 %ile  \
# 0  2.230762e+06  26.95456  2299.52738  18204.50788  ...  1508.86359
# 0  3.265162e+06  43.72227  2126.54706  18394.04963  ...  1697.88753
# 0  5.003156e+06  43.04225  3115.38287  20149.51206  ...  1827.44075
# 0  6.817169e+06  45.89624  3443.53918  22229.37831  ...  1983.30241
# 0  4.782698e+06  34.32556  3539.84743  22980.20397  ...  1894.31066
# 0  1.143975e+02  27.34600    53.93804     26.23359  ...    25.54552
#
#    Qs 50 %ile  SSC 50 %ile  QB 50 %ile   Qw 90 %ile   Qs 90 %ile  SSC 90 %ile  \
# 0    14.88679      0.01108    31.66834  40794.92699  51141.02278      1.23930
# 0    17.84153      0.01275    35.63562  41987.32388  51130.92313      1.19633
# 0    15.34154      0.01039    38.35471  43266.70565  36059.25754      0.83566
# 0    17.04655      0.00998    41.62596  46973.82380  42374.49594      0.89941
# 0    14.57983      0.00945    39.75818  50503.09287  46047.95257      0.91535
# 0    -2.06191    -14.74784    25.54552     23.79748     -9.95887    -26.13991
#
#    QB 90 %ile  DOY Peak Qw  DOY Peak Qs
# 0   856.21238    227.00000    228.00000
# 0   881.23865    226.00000    228.00000
# 0   908.09058    222.00000    224.00000
# 0   985.89635    214.00000    217.00000
# 0  1059.96938    202.00000    224.00000
# 0    23.79748    -11.01322     -1.75439
#
# [6 rows x 31 columns]

# %% [markdown]
# ### 2.1e) NORESM-M

# %%
noresm_2000 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/reference/NORESM-M/summ_stats_v3.csv', dtype=float))
noresm_2020 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/NORESM-M/2020/summ_stats_v3.csv', dtype=float))
noresm_2040 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/NORESM-M/2040/summ_stats_v3.csv', dtype=float))
noresm_2060 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/NORESM-M/2060/summ_stats_v3.csv', dtype=float))
noresm_2080 = pd.DataFrame(pd.read_csv('../../setup/run_2/Ganga/rcp4p5/NORESM-M/2080/summ_stats_v3.csv', dtype=float))

frames_noresm = [noresm_2000, noresm_2020, noresm_2040, noresm_2060, noresm_2080]
concat_noresm = pd.concat(frames_noresm)
concat_noresm.insert(0, 'Time Frame', ['2000', '2020', '2040', '2060', '2080'])

# %%
noresm_change = ((noresm_2080 - noresm_2000)/noresm_2000)*100
concat_noresm = concat_noresm.append(noresm_change)
concat_noresm.round(5)
# Out:
#   Time Frame      Mean Qw      Mean Qs  Mean SSC    Mean Qb        Max Qw  \
# 0       2000  12311.47649  22004.11557   0.38927  258.39582  128654.55820
# 0       2020  15427.11823  25430.71304   0.35303  323.78755  139646.57132
# 0       2040  16368.62919  26864.17343   0.36323  343.54818  141901.99987
# 0       2060  17806.65726  28229.23483   0.33554  373.72981  174932.21083
# 0       2080  18538.47583  28854.56114   0.34268  389.08937  178402.79566
# 0        NaN     50.57882     31.13256 -11.96863   50.57882      38.66807
#
#          Max Qs   Max SSC      Max Qb        SD Qw  ...  Qw 50 %ile  \
# 0  2.767671e+06  32.47280  2700.22852  19853.27845  ...  1589.82729
# 0  4.260108e+06  30.50636  2930.93117  25127.96308  ...  1817.09419
# 0  4.170962e+06  31.61866  2978.26857  26513.87852  ...  1835.02224
# 0  4.449899e+06  29.17968  3671.51348  28708.22258  ...  2029.37303
# 0  4.052385e+06  30.68425  3744.35484  30168.42657  ...  2236.85824
# 0  4.641858e+01  -5.50784    38.66807     51.95690  ...    40.69819
#
#    Qs 50 %ile  SSC 50 %ile  QB 50 %ile   Qw 90 %ile   Qs 90 %ile  SSC 90 %ile  \
# 0    12.12035      0.00882    33.36762  46111.92662  46554.64341      1.02556
# 0    10.54119      0.00704    38.13755  56377.04851  50073.42885      0.89244
# 0    11.11366      0.00740    38.51383  60676.49082  54438.81015      0.90933
# 0    10.94564      0.00626    42.59290  62697.96028  46007.62675      0.72303
# 0    14.92255      0.00797    46.94764  67876.41113  54647.30299      0.80163
# 0    23.11982     -9.55641    40.69819     47.19925     17.38314    -21.83422
#
#    QB 90 %ile  DOY Peak Qw  DOY Peak Qs
# 0   967.80667    228.00000    217.00000
# 0  1183.25317    222.00000    210.00000
# 0  1273.49076    214.00000    217.00000
# 0  1315.91778    223.00000    197.00000
# 0  1424.60418    221.00000    235.00000
# 0    47.19925     -3.07018      8.29493
#
# [6 rows x 31 columns]

# %% [markdown]
# ***Important Note***
#
# Before moving on, check that the data in the summary statistics tables in 2.1 a-e) seem adequate. Values with an exponent of >100 are not accurate, and HydroTrend must be re-run for that specific model run. Do this via the terminal by navigating to the project folder/repository (ht_gbmd), then:
#
# > conda activate pymt
#
# > python setup/run_2/Ganga/rcp4p5/HadGEM2/2060/run_HT_v2.py (or whichever run seems erroneous)
#
# Then clear the kernel and re-run this notebook. See if the error subsided.
#
# This problem occurs due to a wrapping error in HydroTrend, which requires developer input to fix, which is beyond the scope of this project. You may need to re-run the model several times.

# %% [markdown]
# ## 2.2. Calculate average Qw (m^3/s), Qs (kg/s), SSC (mg/l), and Qs (MT/yr)

# %% [markdown]
# ### 2.2a) Average water discharge (over all climate models for each time period)

# %%
avg_qw_ref = np.mean([gfdl_2000['Mean Qw'].to_numpy(), hadgem_2000['Mean Qw'].to_numpy(), ipsl_2000['Mean Qw'].to_numpy(), miroc_2000['Mean Qw'].to_numpy(), noresm_2000['Mean Qw'].to_numpy()])
avg_qw_2020 = np.mean([gfdl_2020['Mean Qw'].to_numpy(), hadgem_2020['Mean Qw'].to_numpy(), ipsl_2020['Mean Qw'].to_numpy(), miroc_2020['Mean Qw'].to_numpy(), noresm_2020['Mean Qw'].to_numpy()])
avg_qw_2040 = np.mean([gfdl_2040['Mean Qw'].to_numpy(), hadgem_2040['Mean Qw'].to_numpy(), ipsl_2040['Mean Qw'].to_numpy(), miroc_2040['Mean Qw'].to_numpy(), noresm_2040['Mean Qw'].to_numpy()])
avg_qw_2060 = np.mean([gfdl_2060['Mean Qw'].to_numpy(), hadgem_2060['Mean Qw'].to_numpy(), ipsl_2060['Mean Qw'].to_numpy(), miroc_2060['Mean Qw'].to_numpy(), noresm_2060['Mean Qw'].to_numpy()])
avg_qw_2080 = np.mean([gfdl_2080['Mean Qw'].to_numpy(), hadgem_2080['Mean Qw'].to_numpy(), ipsl_2080['Mean Qw'].to_numpy(), miroc_2080['Mean Qw'].to_numpy(), noresm_2080['Mean Qw'].to_numpy()])

# %%
print('2000 Avg. Qw (m^3/s): {:.6}'.format(avg_qw_ref))
print('2020 Avg. Qw (m^3/s): {:.6}'.format(avg_qw_2020))
print('2040 Avg. Qw (m^3/s): {:.6}'.format(avg_qw_2040))
print('2060 Avg. Qw (m^3/s): {:.6}'.format(avg_qw_2060))
print('2080 Avg. Qw (m^3/s): {:.6}'.format(avg_qw_2080))
# Out:
# 2000 Avg. Qw (m^3/s): 12793.5
# 2020 Avg. Qw (m^3/s): 14320.3
# 2040 Avg. Qw (m^3/s): 15217.9
# 2060 Avg. Qw (m^3/s): 16963.4
# 2080 Avg. Qw (m^3/s): 17653.5

# %% [markdown]
# ### 2.2b) Average sediment discharge (kg/s)

# %%
avg_qs_ref = np.mean([gfdl_2000['Mean Qs'].to_numpy(), hadgem_2000['Mean Qs'].to_numpy(), ipsl_2000['Mean Qs'].to_numpy(), miroc_2000['Mean Qs'].to_numpy(), noresm_2000['Mean Qs'].to_numpy()])
avg_qs_2020 = np.mean([gfdl_2020['Mean Qs'].to_numpy(), hadgem_2020['Mean Qs'].to_numpy(), ipsl_2020['Mean Qs'].to_numpy(), miroc_2020['Mean Qs'].to_numpy(), noresm_2020['Mean Qs'].to_numpy()])
avg_qs_2040 = np.mean([gfdl_2040['Mean Qs'].to_numpy(), hadgem_2040['Mean Qs'].to_numpy(), ipsl_2040['Mean Qs'].to_numpy(), miroc_2040['Mean Qs'].to_numpy(), noresm_2040['Mean Qs'].to_numpy()])
avg_qs_2060 = np.mean([gfdl_2060['Mean Qs'].to_numpy(), hadgem_2060['Mean Qs'].to_numpy(), ipsl_2060['Mean Qs'].to_numpy(), miroc_2060['Mean Qs'].to_numpy(), noresm_2060['Mean Qs'].to_numpy()])
avg_qs_2080 = np.mean([gfdl_2080['Mean Qs'].to_numpy(), hadgem_2080['Mean Qs'].to_numpy(), ipsl_2080['Mean Qs'].to_numpy(), miroc_2080['Mean Qs'].to_numpy(), noresm_2080['Mean Qs'].to_numpy()])

# %%
print('2000 Avg. Qs (kg/s): {:.6}'.format(avg_qs_ref))
print('2020 Avg. Qs (kg/s): {:.6}'.format(avg_qs_2020))
print('2040 Avg. Qs (kg/s): {:.6}'.format(avg_qs_2040))
print('2060 Avg. Qs (kg/s): {:.6}'.format(avg_qs_2060))
print('2080 Avg. Qs (kg/s): {:.6}'.format(avg_qs_2080))
# Out:
# 2000 Avg. Qs (kg/s): 22481.0
# 2020 Avg. Qs (kg/s): 24695.7
# 2040 Avg. Qs (kg/s): 26042.4
# 2060 Avg. Qs (kg/s): 28195.3
# 2080 Avg. Qs (kg/s): 29171.1

# %% [markdown]
# ### 2.2c) Average SSC (mg/l)

# %%
avg_SSC_ref = np.mean([gfdl_2000['Mean SSC'].to_numpy(), hadgem_2000['Mean SSC'].to_numpy(), ipsl_2000['Mean SSC'].to_numpy(), miroc_2000['Mean SSC'].to_numpy(), noresm_2000['Mean SSC'].to_numpy()])
avg_SSC_2020 = np.mean([gfdl_2020['Mean SSC'].to_numpy(), hadgem_2020['Mean SSC'].to_numpy(), ipsl_2020['Mean SSC'].to_numpy(), miroc_2020['Mean SSC'].to_numpy(), noresm_2020['Mean SSC'].to_numpy()])
avg_SSC_2040 = np.mean([gfdl_2040['Mean SSC'].to_numpy(), hadgem_2040['Mean SSC'].to_numpy(), ipsl_2040['Mean SSC'].to_numpy(), miroc_2040['Mean SSC'].to_numpy(), noresm_2040['Mean SSC'].to_numpy()])
avg_SSC_2060 = np.mean([gfdl_2060['Mean SSC'].to_numpy(), hadgem_2060['Mean SSC'].to_numpy(), ipsl_2060['Mean SSC'].to_numpy(), miroc_2060['Mean SSC'].to_numpy(), noresm_2060['Mean SSC'].to_numpy()])
avg_SSC_2080 = np.mean([gfdl_2080['Mean SSC'].to_numpy(), hadgem_2080['Mean SSC'].to_numpy(), ipsl_2080['Mean SSC'].to_numpy(), miroc_2080['Mean SSC'].to_numpy(), noresm_2080['Mean SSC'].to_numpy()])

# %%
print('2000 Avg. SSC (mg/l): {:.3}'.format(avg_SSC_ref))
print('2020 Avg. SSC (mg/l): {:.3}'.format(avg_SSC_2020))
print('2040 Avg. SSC (mg/l): {:.3}'.format(avg_SSC_2040))
print('2060 Avg. SSC (mg/l): {:.3}'.format(avg_SSC_2060))
print('2080 Avg. SSC (mg/l): {:.3}'.format(avg_SSC_2080))
# Out:
# 2000 Avg. SSC (mg/l): 0.309
# 2020 Avg. SSC (mg/l): 0.315
# 2040 Avg. SSC (mg/l): 0.314
# 2060 Avg. SSC (mg/l): 0.29
# 2080 Avg. SSC (mg/l): 0.322

# %% [markdown]
# ### 2.2d) Annual Average Sediment Discharge (MT/yr)

# %%
print('2000 Avg. Qs (MT/yr): {:.4}'.format(avg_qs_ref*3.14e7/1e9))
print('2020 Avg. Qs (MT/yr): {:.4}'.format(avg_qs_2020*3.14e7/1e9))
print('2040 Avg. Qs (MT/yr): {:.4}'.format(avg_qs_2040*3.14e7/1e9))
print('2060 Avg. Qs (MT/yr): {:.4}'.format(avg_qs_2060*3.14e7/1e9))
print('2080 Avg. Qs (MT/yr): {:.4}'.format(avg_qs_2080*3.14e7/1e9))
# Out:
# 2000 Avg. Qs (MT/yr): 705.9
# 2020 Avg. Qs (MT/yr): 775.4
# 2040 Avg. Qs (MT/yr): 817.7
# 2060 Avg. Qs (MT/yr): 885.3
# 2080 Avg. Qs (MT/yr): 916.0

# %% [markdown]
# # Part 3: Compare and contrast sediment discharge values calculated via different methods**
#
# ## 3.1. Method 1: Sum method (manual averaging)

# %%
# sum all the outputs and divide by the number of outputs
gfdl_qs_kgs_20 = gfdl['Qs(kg/s)'][0:10950].sum()/10950
gfdl_qs_kgs_40 = gfdl['Qs(kg/s)'][7300:18250].sum()/10950
gfdl_qs_kgs_60 = gfdl['Qs(kg/s)'][14600:25550].sum()/10950
gfdl_qs_kgs_80 = gfdl['Qs(kg/s)'][21900:].sum()/10950

hadgem_qs_kgs_20 = hadgem['Qs(kg/s)'][0:10950].sum()/10950
hadgem_qs_kgs_40 = hadgem['Qs(kg/s)'][7300:18250].sum()/10950
hadgem_qs_kgs_60 = hadgem['Qs(kg/s)'][14600:25550].sum()/10950
hadgem_qs_kgs_80 = hadgem['Qs(kg/s)'][21900:].sum()/10950

ipsl_qs_kgs_20 = ipsl['Qs(kg/s)'][0:10950].sum()/10950
ipsl_qs_kgs_40 = ipsl['Qs(kg/s)'][7300:18250].sum()/10950
ipsl_qs_kgs_60 = ipsl['Qs(kg/s)'][14600:25550].sum()/10950
ipsl_qs_kgs_80 = ipsl['Qs(kg/s)'][21900:].sum()/10950

miroc_qs_kgs_20 = miroc['Qs(kg/s)'][0:10950].sum()/10950
miroc_qs_kgs_40 = miroc['Qs(kg/s)'][7300:18250].sum()/10950
miroc_qs_kgs_60 = miroc['Qs(kg/s)'][14600:25550].sum()/10950
miroc_qs_kgs_80 = miroc['Qs(kg/s)'][21900:].sum()/10950

noresm_qs_kgs_20 = noresm['Qs(kg/s)'][0:10950].sum()/10950
noresm_qs_kgs_40 = noresm['Qs(kg/s)'][7300:18250].sum()/10950
noresm_qs_kgs_60 = noresm['Qs(kg/s)'][14600:25550].sum()/10950
noresm_qs_kgs_80 = noresm['Qs(kg/s)'][21900:].sum()/10950

# %%
# convert averages from kg/s to mt/yr
gfdl_qs_mtyr_20 = gfdl_qs_kgs_20*3.14e7/1e9
gfdl_qs_mtyr_40 = gfdl_qs_kgs_40*3.14e7/1e9
gfdl_qs_mtyr_60 = gfdl_qs_kgs_60*3.14e7/1e9
gfdl_qs_mtyr_80 = gfdl_qs_kgs_80*3.14e7/1e9

hadgem_qs_mtyr_20 = hadgem_qs_kgs_20*3.14e7/1e9
hadgem_qs_mtyr_40 = hadgem_qs_kgs_40*3.14e7/1e9
hadgem_qs_mtyr_60 = hadgem_qs_kgs_60*3.14e7/1e9
hadgem_qs_mtyr_80 = hadgem_qs_kgs_80*3.14e7/1e9

ipsl_qs_mtyr_20 = ipsl_qs_kgs_20*3.14e7/1e9
ipsl_qs_mtyr_40 = ipsl_qs_kgs_40*3.14e7/1e9
ipsl_qs_mtyr_60 = ipsl_qs_kgs_60*3.14e7/1e9
ipsl_qs_mtyr_80 = ipsl_qs_kgs_80*3.14e7/1e9

miroc_qs_mtyr_20 = miroc_qs_kgs_20*3.14e7/1e9
miroc_qs_mtyr_40 = miroc_qs_kgs_40*3.14e7/1e9
miroc_qs_mtyr_60 = miroc_qs_kgs_60*3.14e7/1e9
miroc_qs_mtyr_80 = miroc_qs_kgs_80*3.14e7/1e9

noresm_qs_mtyr_20 = noresm_qs_kgs_20*3.14e7/1e9
noresm_qs_mtyr_40 = noresm_qs_kgs_40*3.14e7/1e9
noresm_qs_mtyr_60 = noresm_qs_kgs_60*3.14e7/1e9
noresm_qs_mtyr_80 = noresm_qs_kgs_80*3.14e7/1e9

# %%
print('Annual sediment discharge using sum method (MT/yr):')
print('GFDL: {:.5} (2020), {:.5} (2040), {:.5} (2060), {:.5} (2080)'.format(gfdl_qs_mtyr_20, gfdl_qs_mtyr_40, gfdl_qs_mtyr_60, gfdl_qs_mtyr_80))
print('HadGEM: {:.5} (2020), {:.5} (2040), {:.5} (2060), {:.5} (2080)'.format(hadgem_qs_mtyr_20, hadgem_qs_mtyr_40, hadgem_qs_mtyr_60, hadgem_qs_mtyr_80))
print('IPSL: {:.5} (2020), {:.5} (2040), {:.5} (2060), {:.5} (2080)'.format(ipsl_qs_mtyr_20, ipsl_qs_mtyr_40, ipsl_qs_mtyr_60, ipsl_qs_mtyr_80))
print('MIROC: {:.5} (2020), {:.5} (2040), {:.5} (2060), {:.5} (2080)'.format(miroc_qs_mtyr_20, miroc_qs_mtyr_40, miroc_qs_mtyr_60, miroc_qs_mtyr_80))
print('NORESM: {:.5} (2020), {:.5} (2040), {:.5} (2060), {:.5} (2080)'.format(noresm_qs_mtyr_20, noresm_qs_mtyr_40, noresm_qs_mtyr_60, noresm_qs_mtyr_80))
# Out:
# Annual sediment discharge using sum method (MT/yr):
# GFDL: 712.3 (2020), 885.95 (2040), 796.47 (2060), 1578.8 (2080)
# HadGEM: 704.77 (2020), 994.01 (2040), 795.16 (2060), 1436.5 (2080)
# IPSL: 754.22 (2020), 366.2 (2040), 833.08 (2060), 1648.9 (2080)
# MIROC: 667.3 (2020), 651.41 (2040), 712.38 (2060), 1724.0 (2080)
# NORESM: 690.93 (2020), 707.9 (2040), 731.51 (2060), 1637.9 (2080)

# %%
print('Average annual sediment discharge over all climate models (MT/yr):')
print('2020: {:.5}'.format((gfdl_qs_mtyr_20 + hadgem_qs_mtyr_20 + miroc_qs_mtyr_20 + noresm_qs_mtyr_20)/4))
print('2040: {:.5}'.format((gfdl_qs_mtyr_40 + hadgem_qs_mtyr_40 + miroc_qs_mtyr_40 + noresm_qs_mtyr_40)/4))
print('2060: {:.5}'.format((gfdl_qs_mtyr_60 + hadgem_qs_mtyr_60 + miroc_qs_mtyr_60 + noresm_qs_mtyr_60)/4))
print('2080: {:.5}'.format((gfdl_qs_mtyr_80 + hadgem_qs_mtyr_80 + miroc_qs_mtyr_80 + noresm_qs_mtyr_80)/4))
# Out:
# Average annual sediment discharge over all climate models (MT/yr):
# 2020: 693.82
# 2040: 809.82
# 2060: 758.88
# 2080: 1594.3

# %% [markdown]
# ## 3.2. Method 2: Sediment rating curve method

# %% [markdown]
# ### 3.2a) 2020

# %%
from scipy.optimize import curve_fit
from scipy import stats

# %%
# Calculate new rating curve statistics from HT outputs
gfdl_20 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(gfdl['Qw(m3/s)'][0:10950]), np.log(gfdl['Qs(kg/s)'][0:10950]))
print('gfdl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(gfdl_20.slope, np.exp(gfdl_20.intercept), gfdl_20.rvalue**2))

hadgem_20 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(hadgem['Qw(m3/s)'][0:10950]), np.log(hadgem['Qs(kg/s)'][0:10950]))
print('hadgem: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(hadgem_20.slope, np.exp(hadgem_20.intercept), hadgem_20.rvalue**2))

ipsl_20 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ipsl['Qw(m3/s)'][0:10950]), np.log(ipsl['Qs(kg/s)'][0:10950]))
print('ipsl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(ipsl_20.slope, np.exp(ipsl_20.intercept), ipsl_20.rvalue**2))

miroc_20 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(miroc['Qw(m3/s)'][0:10950]), np.log(miroc['Qs(kg/s)'][0:10950]))
print('miroc: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(miroc_20.slope, np.exp(miroc_20.intercept), miroc_20.rvalue**2))

noresm_20 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(noresm['Qw(m3/s)'][0:10950]), np.log(noresm['Qs(kg/s)'][0:10950]))
print('noresm: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(noresm_20.slope, np.exp(noresm_20.intercept), noresm_20.rvalue**2))
# Out:
# gfdl: slope:2.65    intercept: 2.28e-08    r-squared: 0.95
# hadgem: slope:2.63    intercept: 9.97e-09    r-squared: 0.94
# ipsl: slope:2.62    intercept: 3.55e-09    r-squared: 0.93
# miroc: slope:2.62    intercept: 4.15e-08    r-squared: 0.95
# noresm: slope:2.63    intercept: 2.98e-08    r-squared: 0.95

# %%
# Calculate sediment discharge using slope and interceps above
qs_gfdl_20 = 4.09e-08*(gfdl['Qw(m3/s)'][0:10950]**2.61)   
qs_hadgem_20 = 5.64e-09*(hadgem['Qw(m3/s)'][0:10950]**2.65) 
qs_ipsl_20 = 4.73e-09*(ipsl['Qw(m3/s)'][0:10950]**2.63)       
qs_miroc_20 = 4.85e-08*(miroc['Qw(m3/s)'][0:10950]**2.6)       
qs_noresm_20 = 1.81e-08*(noresm['Qw(m3/s)'][0:10950]**2.62)

# %%
# Take average Qs and convert from kg/s to mt/yr
qs_gfdl_mtyr_20 = (qs_gfdl_20[1:].sum()/10950)*3.14e7/1e9
qs_hadgem_mtyr_20 = (qs_hadgem_20[1:].sum()/10950)*3.14e7/1e9
qs_miroc_mtyr_20 = (qs_miroc_20[1:].sum()/10950)*3.14e7/1e9
qs_noresm_mtyr_20 = (qs_noresm_20[1:].sum()/10950)*3.14e7/1e9

# %%
print('Annual average sediment discharge using rating curve method for 2020 (MT/yr):')
print('GFDL: {:.5}'.format(qs_gfdl_mtyr_20))
print('HadGEM: {:.5}'.format(qs_hadgem_mtyr_20))
print('MIROC: {:.5}'.format(qs_miroc_mtyr_20))
print('NORESM: {:.5}'.format(qs_noresm_mtyr_20))
print('Average: {:.5}'.format((qs_gfdl_mtyr_20 + qs_hadgem_mtyr_20 + qs_miroc_mtyr_20 + qs_noresm_mtyr_20)/4))
# Out:
# Annual average sediment discharge using rating curve method for 2020 (MT/yr):
# GFDL: 612.81
# HadGEM: 308.42
# MIROC: 472.86
# NORESM: 270.73
# Average: 416.21

# %% [markdown]
# ### 3.2b) 2040

# %%
# Calculate new rating curve statistics from HT outputs
gfdl_40 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(gfdl['Qw(m3/s)'][7300:18250]), np.log(gfdl['Qs(kg/s)'][7300:18250]))
print('gfdl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(gfdl_40.slope, np.exp(gfdl_40.intercept), gfdl_40.rvalue**2))

hadgem_40 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(hadgem['Qw(m3/s)'][7300:18250]), np.log(hadgem['Qs(kg/s)'][7300:18250]))
print('hadgem: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(hadgem_40.slope, np.exp(hadgem_40.intercept), hadgem_40.rvalue**2))

ipsl_40 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ipsl['Qw(m3/s)'][7300:18250]), np.log(ipsl['Qs(kg/s)'][7300:18250]))
print('ipsl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(ipsl_40.slope, np.exp(ipsl_40.intercept), ipsl_40.rvalue**2))

miroc_40 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(miroc['Qw(m3/s)'][7300:18250]), np.log(miroc['Qs(kg/s)'][7300:18250]))
print('miroc: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(miroc_40.slope, np.exp(miroc_40.intercept), miroc_40.rvalue**2))

noresm_40 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(noresm['Qw(m3/s)'][7300:18250]), np.log(noresm['Qs(kg/s)'][7300:18250]))
print('noresm: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(noresm_40.slope, np.exp(noresm_40.intercept), noresm_40.rvalue**2))
# Out:
# gfdl: slope:2.62    intercept: 3.35e-08    r-squared: 0.95
# hadgem: slope:2.62    intercept: 7.8e-09    r-squared: 0.92
# ipsl: slope:2.62    intercept: 4.69e-09    r-squared: 0.93
# miroc: slope:2.6    intercept: 5.3e-08    r-squared: 0.95
# noresm: slope:2.6    intercept: 2.71e-08    r-squared: 0.94

# %%
# Calculate sediment discharge using slope and interceps above
qs_gfdl_40 = 3.92e-08*(gfdl['Qw(m3/s)'][7300:18250]**2.61)   
qs_hadgem_40 = 5.01e-09*(hadgem['Qw(m3/s)'][7300:18250]**2.65) 
qs_ipsl_40 = 4.05e-09*(ipsl['Qw(m3/s)'][7300:18250]**2.62)       
qs_miroc_40 = 3.37e-08*(miroc['Qw(m3/s)'][7300:18250]**2.61)       
qs_noresm_40 = 1.3e-08*(noresm['Qw(m3/s)'][7300:18250]**2.64)

# %%
# Take average Qs and convert from kg/s to mt/yr
qs_gfdl_mtyr_40 = (qs_gfdl_40[1:].sum()/10950)*3.14e7/1e9
qs_hadgem_mtyr_40 = (qs_hadgem_40[1:].sum()/10950)*3.14e7/1e9
qs_miroc_mtyr_40 = (qs_miroc_40[1:].sum()/10950)*3.14e7/1e9
qs_noresm_mtyr_40 = (qs_noresm_40[1:].sum()/10950)*3.14e7/1e9

# %%
print('Annual average sediment discharge using rating curve method for 2040 (MT/yr):')
print('GFDL: {:.5}'.format(qs_gfdl_mtyr_40))
print('HadGEM: {:.5}'.format(qs_hadgem_mtyr_40))
print('MIROC: {:.5}'.format(qs_miroc_mtyr_40))
print('NORESM: {:.5}'.format(qs_noresm_mtyr_40))
print('Average: {:.5}'.format((qs_gfdl_mtyr_40 + qs_hadgem_mtyr_40 + qs_miroc_mtyr_40 + qs_noresm_mtyr_40)/4))
# Out:
# Annual average sediment discharge using rating curve method for 2040 (MT/yr):
# GFDL: 628.81
# HadGEM: 403.39
# MIROC: 347.06
# NORESM: 344.85
# Average: 431.03

# %% [markdown]
# ### 3.2c) 2060

# %%
# Calculate new rating curve statistics from HT outputs
gfdl_60 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(gfdl['Qw(m3/s)'][14600:25550]), np.log(gfdl['Qs(kg/s)'][14600:25550]))
print('gfdl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(gfdl_60.slope, np.exp(gfdl_60.intercept), gfdl_60.rvalue**2))

hadgem_60 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(hadgem['Qw(m3/s)'][14600:25550]), np.log(hadgem['Qs(kg/s)'][14600:25550]))
print('hadgem: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(hadgem_60.slope, np.exp(hadgem_60.intercept), hadgem_60.rvalue**2))

ipsl_60 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ipsl['Qw(m3/s)'][14600:25550]), np.log(ipsl['Qs(kg/s)'][14600:25550]))
print('ipsl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(ipsl_60.slope, np.exp(ipsl_60.intercept), ipsl_60.rvalue**2))

miroc_60 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(miroc['Qw(m3/s)'][14600:25550]), np.log(miroc['Qs(kg/s)'][14600:25550]))
print('miroc: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(miroc_60.slope, np.exp(miroc_60.intercept), miroc_60.rvalue**2))

noresm_60 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(noresm['Qw(m3/s)'][14600:25550]), np.log(noresm['Qs(kg/s)'][14600:25550]))
print('noresm: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(noresm_60.slope, np.exp(noresm_60.intercept), noresm_60.rvalue**2))
# Out:
# gfdl: slope:2.57    intercept: 5.9e-08    r-squared: 0.94
# hadgem: slope:2.61    intercept: 8.28e-09    r-squared: 0.91
# ipsl: slope:2.6    intercept: 6.04e-09    r-squared: 0.91
# miroc: slope:2.58    intercept: 4.97e-08    r-squared: 0.94
# noresm: slope:2.62    intercept: 1.88e-08    r-squared: 0.93

# %%
# Calculate sediment discharge using slope and interceps above
qs_gfdl_60 = 2.89e-08*(gfdl['Qw(m3/s)'][14600:25550]**2.62)   
qs_hadgem_60 = 4.58e-09*(hadgem['Qw(m3/s)'][14600:25550]**2.62) 
qs_ipsl_60 = 3.57e-09*(ipsl['Qw(m3/s)'][14600:25550]**2.62)       
qs_miroc_60 = 2.91e-08*(miroc['Qw(m3/s)'][14600:25550]**2.61)       
qs_noresm_60 = 1.22e-08*(noresm['Qw(m3/s)'][14600:25550]**2.63)

# %%
# Take average Qs and convert from kg/s to mt/yr
qs_gfdl_mtyr_60 = (qs_gfdl_60[1:].sum()/10950)*3.14e7/1e9
qs_hadgem_mtyr_60 = (qs_hadgem_60[1:].sum()/10950)*3.14e7/1e9
qs_miroc_mtyr_60 = (qs_miroc_60[1:].sum()/10950)*3.14e7/1e9
qs_noresm_mtyr_60 = (qs_noresm_60[1:].sum()/10950)*3.14e7/1e9

# %%
print('Annual average sediment discharge using rating curve method for 2060 (MT/yr):')
print('GFDL: {:.5}'.format(qs_gfdl_mtyr_60))
print('HadGEM: {:.5}'.format(qs_hadgem_mtyr_60))
print('MIROC: {:.5}'.format(qs_miroc_mtyr_60))
print('NORESM: {:.5}'.format(qs_noresm_mtyr_60))
print('Average: {:.5}'.format((qs_gfdl_mtyr_60 + qs_hadgem_mtyr_60 + qs_miroc_mtyr_60 + qs_noresm_mtyr_60)/4))
# Out:
# Annual average sediment discharge using rating curve method for 2060 (MT/yr):
# GFDL: 433.64
# HadGEM: 277.04
# MIROC: 339.32
# NORESM: 373.62
# Average: 355.91

# %% [markdown]
# ### 3.2d) 2080

# %%
# Calculate new rating curve statistics from HT outputs
gfdl_80 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(gfdl['Qw(m3/s)'][21900:]), np.log(gfdl['Qs(kg/s)'][21900:]))
print('gfdl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(gfdl_80.slope, np.exp(gfdl_80.intercept), gfdl_80.rvalue**2))

hadgem_80 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(hadgem['Qw(m3/s)'][21900:]), np.log(hadgem['Qs(kg/s)'][21900:]))
print('hadgem: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(hadgem_80.slope, np.exp(hadgem_80.intercept), hadgem_80.rvalue**2))

ipsl_80 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ipsl['Qw(m3/s)'][21900:]), np.log(ipsl['Qs(kg/s)'][21900:]))
print('ipsl: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(ipsl_80.slope, np.exp(ipsl_80.intercept), ipsl_80.rvalue**2))

miroc_80 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(miroc['Qw(m3/s)'][21900:]), np.log(miroc['Qs(kg/s)'][21900:]))
print('miroc: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(miroc_80.slope, np.exp(miroc_80.intercept), miroc_80.rvalue**2))

noresm_80 = slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(noresm['Qw(m3/s)'][21900:]), np.log(noresm['Qs(kg/s)'][21900:]))
print('noresm: slope:{:.3}    intercept: {:.3}    r-squared: {:.2}'.format(noresm_80.slope, np.exp(noresm_80.intercept), noresm_80.rvalue**2))
# Out:
# gfdl: slope:2.58    intercept: 4.03e-08    r-squared: 0.94
# hadgem: slope:2.61    intercept: 6.79e-09    r-squared: 0.9
# ipsl: slope:2.6    intercept: 5.57e-09    r-squared: 0.89
# miroc: slope:2.59    intercept: 3.68e-08    r-squared: 0.94
# noresm: slope:2.62    intercept: 1.49e-08    r-squared: 0.92

# %%
# Calculate sediment discharge using slope and interceps above
qs_gfdl_80 = 3.64e-08*(gfdl['Qw(m3/s)'][14600:25550]**2.59)   
qs_hadgem_80 = 8.11e-09*(hadgem['Qw(m3/s)'][14600:25550]**2.61) 
qs_ipsl_80 = 7.91e-09*(ipsl['Qw(m3/s)'][14600:25550]**2.59)       
qs_miroc_80 = 3.44e-08*(miroc['Qw(m3/s)'][14600:25550]**2.59)       
qs_noresm_80 = 1.27e-08*(noresm['Qw(m3/s)'][14600:25550]**2.63)

# %%
# Take average Qs and convert from kg/s to mt/yr
qs_gfdl_mtyr_80 = (qs_gfdl_80[1:].sum()/10950)*3.14e7/1e9
qs_hadgem_mtyr_80 = (qs_hadgem_80[1:].sum()/10950)*3.14e7/1e9
qs_miroc_mtyr_80 = (qs_miroc_80[1:].sum()/10950)*3.14e7/1e9
qs_noresm_mtyr_80 = (qs_noresm_80[1:].sum()/10950)*3.14e7/1e9

# %%
print('Annual average sediment discharge using rating curve method for 2080 (MT/yr):')
print('GFDL: {:.5}'.format(qs_gfdl_mtyr_80))
print('HadGEM: {:.5}'.format(qs_hadgem_mtyr_80))
print('MIROC: {:.5}'.format(qs_miroc_mtyr_80))
print('NORESM: {:.5}'.format(qs_noresm_mtyr_80))
print('Average: {:.5}'.format((qs_gfdl_mtyr_80 + qs_hadgem_mtyr_80 + qs_miroc_mtyr_80 + qs_noresm_mtyr_80)/4))
# Out:
# Annual average sediment discharge using rating curve method for 2080 (MT/yr):
# GFDL: 390.96
# HadGEM: 436.54
# MIROC: 322.2
# NORESM: 388.94
# Average: 384.66
